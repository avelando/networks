# %%
from functools import partial

from link_prediction.config import (
    load_methods_config,
)
from link_prediction.evaluation import (
    run_method_family_benchmark,
)
from link_prediction.methods.quasi_local_walks import (
    score_quasi_local_walk_candidates,
)

# %%
methods_config = (
    load_methods_config()[
        "methods"
    ]
)

walk_method_ids = [
    "lrw",
    "srw",
    "pfp",
]

configured_steps = {
    methods_config[
        method_id
    ][
        "parameters"
    ][
        "steps"
    ]
    for method_id
    in walk_method_ids
}

if len(
    configured_steps
) != 1:
    raise ValueError(
        "LRW, SRW, and PFP must use "
        "the same primary step configuration."
    )

steps = configured_steps.pop()

walk_scorer = partial(
    score_quasi_local_walk_candidates,
    steps=steps,
)

fold_metrics, network_summary = (
    run_method_family_benchmark(
        family_id="quasi_local_walk",
        scorer=walk_scorer,
        benchmark_name="standard",
    )
)

fold_metrics
# Out:
# quasi_local_walk: 40 tasks, 6 workers
#     benchmark      network_id         network          domain  fold  \
# 0    standard    ego_facebook    ego-Facebook          social     1
# 1    standard    ego_facebook    ego-Facebook          social     1
# 2    standard    ego_facebook    ego-Facebook          social     1
# 3    standard    ego_facebook    ego-Facebook          social     2
# 4    standard    ego_facebook    ego-Facebook          social     2
# ..        ...             ...             ...             ...   ...
# 115  standard  power_1138_bus  power-1138-bus  infrastructure     4
# 116  standard  power_1138_bus  power-1138-bus  infrastructure     4
# 117  standard  power_1138_bus  power-1138-bus  infrastructure     5
# 118  standard  power_1138_bus  power-1138-bus  infrastructure     5
# 119  standard  power_1138_bus  power-1138-bus  infrastructure     5
#
#                family method_id  average_precision   roc_auc  precision  ...  \
# 0    quasi_local_walk       lrw           0.994451  0.995199   0.973397  ...
# 1    quasi_local_walk       srw           0.995554  0.996182   0.976128  ...
# 2    quasi_local_walk       pfp           0.984803  0.989894   0.961461  ...
# 3    quasi_local_walk       lrw           0.995015  0.995677   0.973989  ...
# 4    quasi_local_walk       srw           0.996068  0.996599   0.976899  ...
# ..                ...       ...                ...       ...        ...  ...
# 115  quasi_local_walk       srw           0.833567  0.836182   0.812500  ...
# 116  quasi_local_walk       pfp           0.842312  0.840332   0.812500  ...
# 117  quasi_local_walk       lrw           0.671875  0.671875   0.593750  ...
# 118  quasi_local_walk       srw           0.757812  0.757812   0.687500  ...
# 119  quasi_local_walk       pfp           0.757812  0.757812   0.687500  ...
#
#      tied_candidate_ratio  largest_tie_group  cutoff_score  cutoff_tie_size  \
# 0                0.404097              11723  4.709657e-07                1
# 1                0.404008              11714  1.058775e-06                1
# 2                0.375416              11714  1.962080e-03                1
# 3                0.404982              11267  4.367414e-07                1
# 4                0.404626              11263  9.923205e-07                1
# ..                    ...                ...           ...              ...
# 115              0.796875                 83  0.000000e+00               83
# 116              0.765625                 83  0.000000e+00               83
# 117              0.867188                106  0.000000e+00              106
# 118              0.859375                 95  0.000000e+00               95
# 119              0.812500                 95  0.000000e+00               95
#
#      cutoff_tie_positive_count  cutoff_tie_negative_count  \
# 0                            0                          1
# 1                            1                          0
# 2                            0                          1
# 3                            1                          0
# 4                            0                          1
# ..                         ...                        ...
# 115                         20                         63
# 116                         20                         63
# 117                         42                         64
# 118                         31                         64
# 119                         31                         64
#
#      cutoff_slots_in_tie  cutoff_tie_crosses_boundary  method  \
# 0                      1                        False  LRW-l3
# 1                      1                        False  SRW-l3
# 2                      1                        False  PFP-l3
# 3                      1                        False  LRW-l3
# 4                      1                        False  SRW-l3
# ..                   ...                          ...     ...
# 115                   19                         True  SRW-l3
# 116                   19                         True  PFP-l3
# 117                   42                         True  LRW-l3
# 118                   31                         True  SRW-l3
# 119                   31                         True  PFP-l3
#
#      family_scoring_seconds
# 0                 42.009355
# 1                 42.009355
# 2                 42.009355
# 3                 43.307357
# 4                 43.307357
# ..                      ...
# 115                0.015737
# 116                0.015737
# 117                0.017507
# 118                0.017507
# 119                0.017507
#
# [120 rows x 30 columns]

# %%
network_summary
# Out:
#    benchmark          network_id             network  \
# 0   standard        ego_facebook        ego-Facebook
# 1   standard        ego_facebook        ego-Facebook
# 2   standard        ego_facebook        ego-Facebook
# 3   standard  socfb_middlebury45  socfb-Middlebury45
# 4   standard  socfb_middlebury45  socfb-Middlebury45
# 5   standard  socfb_middlebury45  socfb-Middlebury45
# 6   standard             ca_grqc             ca-GrQc
# 7   standard             ca_grqc             ca-GrQc
# 8   standard             ca_grqc             ca-GrQc
# 9   standard            ca_hepth            ca-HepTh
# 10  standard            ca_hepth            ca-HepTh
# 11  standard            ca_hepth            ca-HepTh
# 12  standard       email_eu_core       email-Eu-core
# 13  standard       email_eu_core       email-Eu-core
# 14  standard       email_eu_core       email-Eu-core
# 15  standard          email_univ          email-univ
# 16  standard          email_univ          email-univ
# 17  standard          email_univ          email-univ
# 18  standard          power_grid          power-grid
# 19  standard          power_grid          power-grid
# 20  standard          power_grid          power-grid
# 21  standard      power_1138_bus      power-1138-bus
# 22  standard      power_1138_bus      power-1138-bus
# 23  standard      power_1138_bus      power-1138-bus
#
#                       domain            family method_id  method  \
# 0                     social  quasi_local_walk       lrw  LRW-l3
# 1                     social  quasi_local_walk       srw  SRW-l3
# 2                     social  quasi_local_walk       pfp  PFP-l3
# 3                     social  quasi_local_walk       lrw  LRW-l3
# 4                     social  quasi_local_walk       srw  SRW-l3
# 5                     social  quasi_local_walk       pfp  PFP-l3
# 6   scientific_collaboration  quasi_local_walk       lrw  LRW-l3
# 7   scientific_collaboration  quasi_local_walk       srw  SRW-l3
# 8   scientific_collaboration  quasi_local_walk       pfp  PFP-l3
# 9   scientific_collaboration  quasi_local_walk       lrw  LRW-l3
# 10  scientific_collaboration  quasi_local_walk       srw  SRW-l3
# 11  scientific_collaboration  quasi_local_walk       pfp  PFP-l3
# 12             communication  quasi_local_walk       lrw  LRW-l3
# 13             communication  quasi_local_walk       srw  SRW-l3
# 14             communication  quasi_local_walk       pfp  PFP-l3
# 15             communication  quasi_local_walk       lrw  LRW-l3
# 16             communication  quasi_local_walk       srw  SRW-l3
# 17             communication  quasi_local_walk       pfp  PFP-l3
# 18            infrastructure  quasi_local_walk       lrw  LRW-l3
# 19            infrastructure  quasi_local_walk       srw  SRW-l3
# 20            infrastructure  quasi_local_walk       pfp  PFP-l3
# 21            infrastructure  quasi_local_walk       lrw  LRW-l3
# 22            infrastructure  quasi_local_walk       srw  SRW-l3
# 23            infrastructure  quasi_local_walk       pfp  PFP-l3
#
#     average_precision_mean  average_precision_std  roc_auc_mean  ...  \
# 0                 0.994835               0.000456      0.995551  ...
# 1                 0.995854               0.000335      0.996441  ...
# 2                 0.984820               0.000704      0.990137  ...
# 3                 0.931820               0.001020      0.938658  ...
# 4                 0.951415               0.000979      0.955407  ...
# 5                 0.918140               0.002466      0.934823  ...
# 6                 0.953424               0.004969      0.952426  ...
# 7                 0.983031               0.002868      0.982669  ...
# 8                 0.981090               0.003936      0.981571  ...
# 9                 0.925999               0.002569      0.924767  ...
# 10                0.968730               0.001937      0.968185  ...
# 11                0.967740               0.001783      0.967600  ...
# 12                0.949512               0.002235      0.953039  ...
# 13                0.956437               0.002038      0.958995  ...
# 14                0.919035               0.004397      0.931056  ...
# 15                0.930379               0.002864      0.925263  ...
# 16                0.938723               0.004516      0.933973  ...
# 17                0.918954               0.006503      0.923381  ...
# 18                0.690656               0.002798      0.691045  ...
# 19                0.770728               0.010568      0.771159  ...
# 20                0.769256               0.010074      0.770938  ...
# 21                0.701271               0.040060      0.709474  ...
# 22                0.811419               0.035516      0.811564  ...
# 23                0.809471               0.038319      0.811356  ...
#
#     cutoff_tie_size_mean  cutoff_tie_size_std  cutoff_tie_positive_count_mean  \
# 0                    1.0             0.000000                             0.6
# 1                    1.0             0.000000                             0.6
# 2                    1.0             0.000000                             0.8
# 3                    1.0             0.000000                             0.2
# 4                    1.0             0.000000                             0.4
# 5                    1.0             0.000000                             0.6
# 6                 1971.2            11.454257                           167.6
# 7                 1493.4           834.292694                            51.2
# 8                 1493.4           834.292694                            51.2
# 9                 3625.8            22.532199                           467.2
# 10                3354.6            17.184295                           196.0
# 11                3354.6            17.184295                           196.0
# 12                   1.0             0.000000                             0.8
# 13                   1.0             0.000000                             0.6
# 14                   1.0             0.000000                             0.6
# 15                   1.2             0.447214                             0.2
# 16                   1.0             0.000000                             0.4
# 17                   1.0             0.000000                             0.6
# 18                 532.2             3.962323                           203.0
# 19                 479.0             7.483315                           150.0
# 20                 479.0             7.483315                           150.0
# 21                  99.8             5.403702                            36.4
# 22                  87.0             4.949747                            23.6
# 23                  87.0             4.949747                            23.6
#
#     cutoff_tie_positive_count_std  cutoff_tie_negative_count_mean  \
# 0                        0.547723                             0.4
# 1                        0.547723                             0.4
# 2                        0.447214                             0.2
# 3                        0.447214                             0.8
# 4                        0.547723                             0.6
# 5                        0.547723                             0.4
# 6                       17.242390                          1803.6
# 7                       28.873864                          1442.2
# 8                       28.873864                          1442.2
# 9                       17.584084                          3158.6
# 10                      12.649111                          3158.6
# 11                      12.649111                          3158.6
# 12                       0.447214                             0.2
# 13                       0.547723                             0.4
# 14                       0.547723                             0.4
# 15                       0.447214                             1.0
# 16                       0.547723                             0.6
# 17                       0.547723                             0.4
# 18                       2.915476                           329.2
# 19                       7.280110                           329.0
# 20                       7.280110                           329.0
# 21                       5.412947                            63.4
# 22                       4.774935                            63.4
# 23                       4.774935                            63.4
#
#     cutoff_tie_negative_count_std  cutoff_slots_in_tie_mean  \
# 0                        0.547723                       1.0
# 1                        0.547723                       1.0
# 2                        0.447214                       1.0
# 3                        0.447214                       1.0
# 4                        0.547723                       1.0
# 5                        0.547723                       1.0
# 6                        6.268971                     118.2
# 7                      805.676548                      11.0
# 8                      805.676548                      11.0
# 9                        7.402702                     392.0
# 10                       7.402702                     120.8
# 11                       7.402702                     120.8
# 12                       0.447214                       1.0
# 13                       0.547723                       1.0
# 14                       0.547723                       1.0
# 15                       0.707107                       1.2
# 16                       0.547723                       1.0
# 17                       0.547723                       1.0
# 18                       1.095445                     201.4
# 19                       1.224745                     148.2
# 20                       1.224745                     148.2
# 21                       0.547723                      35.6
# 22                       0.547723                      22.8
# 23                       0.547723                      22.8
#
#     cutoff_slots_in_tie_std  cutoff_tie_crosses_boundary_mean  \
# 0                  0.000000                               0.0
# 1                  0.000000                               0.0
# 2                  0.000000                               0.0
# 3                  0.000000                               0.0
# 4                  0.000000                               0.0
# 5                  0.000000                               0.0
# 6                 11.454257                               1.0
# 7                  7.582875                               0.8
# 8                  7.582875                               0.8
# 9                 22.770595                               1.0
# 10                17.340704                               1.0
# 11                17.340704                               1.0
# 12                 0.000000                               0.0
# 13                 0.000000                               0.0
# 14                 0.000000                               0.0
# 15                 0.447214                               0.0
# 16                 0.000000                               0.0
# 17                 0.000000                               0.0
# 18                 4.037326                               1.0
# 19                 7.823043                               1.0
# 20                 7.823043                               1.0
# 21                 5.504544                               1.0
# 22                 5.019960                               1.0
# 23                 5.019960                               1.0
#
#     cutoff_tie_crosses_boundary_std
# 0                          0.000000
# 1                          0.000000
# 2                          0.000000
# 3                          0.000000
# 4                          0.000000
# 5                          0.000000
# 6                          0.000000
# 7                          0.447214
# 8                          0.447214
# 9                          0.000000
# 10                         0.000000
# 11                         0.000000
# 12                         0.000000
# 13                         0.000000
# 14                         0.000000
# 15                         0.000000
# 16                         0.000000
# 17                         0.000000
# 18                         0.000000
# 19                         0.000000
# 20                         0.000000
# 21                         0.000000
# 22                         0.000000
# 23                         0.000000
#
# [24 rows x 39 columns]
