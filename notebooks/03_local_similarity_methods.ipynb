# %%
from link_prediction.evaluation import (
    run_method_family_benchmark,
)

from link_prediction.methods.local_similarity import (
    score_local_similarity_candidates,
)

# %%
fold_metrics, network_summary = (
    run_method_family_benchmark(
        family_id="local_similarity",
        scorer=score_local_similarity_candidates,
        benchmark_name="standard",
    )
)

fold_metrics
# Out:
# local_similarity: 40 tasks, 6 workers
#     benchmark      network_id         network          domain  fold  \
# 0    standard    ego_facebook    ego-Facebook          social     1
# 1    standard    ego_facebook    ego-Facebook          social     1
# 2    standard    ego_facebook    ego-Facebook          social     1
# 3    standard    ego_facebook    ego-Facebook          social     1
# 4    standard    ego_facebook    ego-Facebook          social     1
# ..        ...             ...             ...             ...   ...
# 355  standard  power_1138_bus  power-1138-bus  infrastructure     5
# 356  standard  power_1138_bus  power-1138-bus  infrastructure     5
# 357  standard  power_1138_bus  power-1138-bus  infrastructure     5
# 358  standard  power_1138_bus  power-1138-bus  infrastructure     5
# 359  standard  power_1138_bus  power-1138-bus  infrastructure     5
#
#                family method_id  average_precision   roc_auc  precision  ...  \
# 0    local_similarity        cn           0.989987  0.992123   0.971081  ...
# 1    local_similarity        aa           0.992106  0.993196   0.974762  ...
# 2    local_similarity        ra           0.993997  0.994358   0.976188  ...
# 3    local_similarity        ja           0.987786  0.989799   0.953207  ...
# 4    local_similarity        sa           0.988616  0.990847   0.960689  ...
# ..                ...       ...                ...       ...        ...  ...
# 355  local_similarity        sa           0.664062  0.664062   0.593750  ...
# 356  local_similarity        so           0.664062  0.664062   0.593750  ...
# 357  local_similarity       hpi           0.664062  0.664062   0.593750  ...
# 358  local_similarity       hdi           0.664062  0.664062   0.593750  ...
# 359  local_similarity      llhn           0.664062  0.664062   0.593750  ...
#
#      tied_candidate_ratio  largest_tie_group  cutoff_score  cutoff_tie_size  \
# 0                0.999822              14740      2.000000              536
# 1                0.501158              14740      0.474457                1
# 2                0.501871              14740      0.034251                1
# 3                0.922150              14740      0.038462               36
# 4                0.647061              14740      0.102699                1
# ..                    ...                ...           ...              ...
# 355              0.937500                107      0.000000              107
# 356              0.945312                107      0.000000              107
# 357              0.976562                107      0.000000              107
# 358              0.968750                107      0.000000              107
# 359              0.937500                107      0.000000              107
#
#      cutoff_tie_positive_count  cutoff_tie_negative_count  \
# 0                          281                        255
# 1                            1                          0
# 2                            0                          1
# 3                           16                         20
# 4                            1                          0
# ..                         ...                        ...
# 355                         43                         64
# 356                         43                         64
# 357                         43                         64
# 358                         43                         64
# 359                         43                         64
#
#      cutoff_slots_in_tie  cutoff_tie_crosses_boundary  method  \
# 0                    221                         True      CN
# 1                      1                        False      AA
# 2                      1                        False      RA
# 3                     32                         True      JA
# 4                      1                        False      SA
# ..                   ...                          ...     ...
# 355                   43                         True      SA
# 356                   43                         True      SO
# 357                   43                         True     HPI
# 358                   43                         True     HDI
# 359                   43                         True    LLHN
#
#      family_scoring_seconds
# 0                  1.388230
# 1                  1.388230
# 2                  1.388230
# 3                  1.388230
# 4                  1.388230
# ..                      ...
# 355                0.004475
# 356                0.004475
# 357                0.004475
# 358                0.004475
# 359                0.004475
#
# [360 rows x 30 columns]

# %%
network_summary
# Out:
#    benchmark      network_id         network          domain  \
# 0   standard    ego_facebook    ego-Facebook          social
# 1   standard    ego_facebook    ego-Facebook          social
# 2   standard    ego_facebook    ego-Facebook          social
# 3   standard    ego_facebook    ego-Facebook          social
# 4   standard    ego_facebook    ego-Facebook          social
# ..       ...             ...             ...             ...
# 67  standard  power_1138_bus  power-1138-bus  infrastructure
# 68  standard  power_1138_bus  power-1138-bus  infrastructure
# 69  standard  power_1138_bus  power-1138-bus  infrastructure
# 70  standard  power_1138_bus  power-1138-bus  infrastructure
# 71  standard  power_1138_bus  power-1138-bus  infrastructure
#
#               family method_id method  average_precision_mean  \
# 0   local_similarity        cn     CN                0.990847
# 1   local_similarity        aa     AA                0.992898
# 2   local_similarity        ra     RA                0.994423
# 3   local_similarity        ja     JA                0.988833
# 4   local_similarity        sa     SA                0.989574
# ..               ...       ...    ...                     ...
# 67  local_similarity        sa     SA                0.702548
# 68  local_similarity        so     SO                0.702548
# 69  local_similarity       hpi    HPI                0.702548
# 70  local_similarity       hdi    HDI                0.702548
# 71  local_similarity      llhn   LLHN                0.702548
#
#     average_precision_std  roc_auc_mean  ...  cutoff_tie_size_mean  \
# 0                0.000669      0.992723  ...                 558.6
# 1                0.000586      0.993757  ...                   1.8
# 2                0.000406      0.994788  ...                   1.4
# 3                0.000978      0.990458  ...                  27.6
# 4                0.000994      0.991451  ...                   4.6
# ..                    ...           ...  ...                   ...
# 67               0.035283      0.702548  ...                 102.4
# 68               0.035283      0.702548  ...                 102.4
# 69               0.035283      0.702548  ...                 102.4
# 70               0.035283      0.702548  ...                 102.4
# 71               0.035283      0.702548  ...                 102.4
#
#     cutoff_tie_size_std  cutoff_tie_positive_count_mean  \
# 0             39.715236                           325.6
# 1              1.788854                             1.4
# 2              0.894427                             1.2
# 3             15.404545                             9.0
# 4              4.505552                             1.8
# ..                  ...                             ...
# 67             4.774935                            38.2
# 68             4.774935                            38.2
# 69             4.774935                            38.2
# 70             4.774935                            38.2
# 71             4.774935                            38.2
#
#     cutoff_tie_positive_count_std  cutoff_tie_negative_count_mean  \
# 0                       42.576989                           233.0
# 1                        1.516575                             0.4
# 2                        1.095445                             0.2
# 3                        6.244998                            18.6
# 4                        0.836660                             2.8
# ..                            ...                             ...
# 67                       4.604346                            64.2
# 68                       4.604346                            64.2
# 69                       4.604346                            64.2
# 70                       4.604346                            64.2
# 71                       4.604346                            64.2
#
#     cutoff_tie_negative_count_std  cutoff_slots_in_tie_mean  \
# 0                       17.044061                     267.4
# 1                        0.547723                       1.6
# 2                        0.447214                       1.0
# 3                       11.260551                      19.8
# 4                        3.834058                       2.8
# ..                            ...                       ...
# 67                       0.447214                      38.2
# 68                       0.447214                      38.2
# 69                       0.447214                      38.2
# 70                       0.447214                      38.2
# 71                       0.447214                      38.2
#
#     cutoff_slots_in_tie_std  cutoff_tie_crosses_boundary_mean  \
# 0                 63.366395                               1.0
# 1                  1.341641                               0.2
# 2                  0.000000                               0.2
# 3                 12.988456                               0.8
# 4                  3.033150                               0.6
# ..                      ...                               ...
# 67                 4.604346                               1.0
# 68                 4.604346                               1.0
# 69                 4.604346                               1.0
# 70                 4.604346                               1.0
# 71                 4.604346                               1.0
#
#     cutoff_tie_crosses_boundary_std
# 0                          0.000000
# 1                          0.447214
# 2                          0.447214
# 3                          0.447214
# 4                          0.547723
# ..                              ...
# 67                         0.000000
# 68                         0.000000
# 69                         0.000000
# 70                         0.000000
# 71                         0.000000
#
# [72 rows x 39 columns]
