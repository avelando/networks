# %%
from link_prediction.evaluation import (
    run_method_family_benchmark,
)

from link_prediction.methods.local_similarity import (
    score_local_similarity_candidates,
)

# %%
fold_metrics, network_summary = (
    run_method_family_benchmark(
        family_id="local_similarity",
        scorer=score_local_similarity_candidates,
        benchmark_name="revision",
    )
)

fold_metrics
# Out:
#     benchmark      network_id         network          domain  fold  \
# 0    revision    ego_facebook    ego-Facebook          social     1
# 1    revision    ego_facebook    ego-Facebook          social     1
# 2    revision    ego_facebook    ego-Facebook          social     1
# 3    revision    ego_facebook    ego-Facebook          social     1
# 4    revision    ego_facebook    ego-Facebook          social     1
# ..        ...             ...             ...             ...   ...
# 355  revision  power_1138_bus  power-1138-bus  infrastructure     5
# 356  revision  power_1138_bus  power-1138-bus  infrastructure     5
# 357  revision  power_1138_bus  power-1138-bus  infrastructure     5
# 358  revision  power_1138_bus  power-1138-bus  infrastructure     5
# 359  revision  power_1138_bus  power-1138-bus  infrastructure     5
#
#                family method_id  average_precision   roc_auc  precision  \
# 0    local_similarity        cn           0.991589  0.992123   0.971081
# 1    local_similarity        aa           0.992819  0.993196   0.974762
# 2    local_similarity        ra           0.994709  0.994358   0.976188
# 3    local_similarity        ja           0.988472  0.989799   0.953207
# 4    local_similarity        sa           0.989274  0.990847   0.960689
# ..                ...       ...                ...       ...        ...
# 355  local_similarity        sa           0.745160  0.664062   0.593750
# 356  local_similarity        so           0.745160  0.664062   0.593750
# 357  local_similarity       hpi           0.745160  0.664062   0.593750
# 358  local_similarity       hdi           0.745160  0.664062   0.593750
# 359  local_similarity      llhn           0.745160  0.664062   0.593750
#
#        recall        f1      ndcg  cutoff  positive_count  negative_count  \
# 0    0.971081  0.971081  0.973959   16840           16840           16840
# 1    0.974762  0.974762  0.977286   16840           16840           16840
# 2    0.976188  0.976188  0.978733   16840           16840           16840
# 3    0.953207  0.953207  0.957400   16840           16840           16840
# 4    0.960689  0.960689  0.963984   16840           16840           16840
# ..        ...       ...       ...     ...             ...             ...
# 355  0.593750  0.593750  0.685342      64              64              64
# 356  0.593750  0.593750  0.685342      64              64              64
# 357  0.593750  0.593750  0.685342      64              64              64
# 358  0.593750  0.593750  0.685342      64              64              64
# 359  0.593750  0.593750  0.685342      64              64              64
#
#      candidate_count method  family_scoring_seconds
# 0              33680     CN                0.434126
# 1              33680     AA                0.434126
# 2              33680     RA                0.434126
# 3              33680     JA                0.434126
# 4              33680     SA                0.434126
# ..               ...    ...                     ...
# 355              128     SA                0.001599
# 356              128     SO                0.001599
# 357              128    HPI                0.001599
# 358              128    HDI                0.001599
# 359              128   LLHN                0.001599
#
# [360 rows x 19 columns]

# %%
network_summary
# Out:
#    benchmark      network_id         network          domain  \
# 0   revision    ego_facebook    ego-Facebook          social
# 1   revision    ego_facebook    ego-Facebook          social
# 2   revision    ego_facebook    ego-Facebook          social
# 3   revision    ego_facebook    ego-Facebook          social
# 4   revision    ego_facebook    ego-Facebook          social
# ..       ...             ...             ...             ...
# 67  revision  power_1138_bus  power-1138-bus  infrastructure
# 68  revision  power_1138_bus  power-1138-bus  infrastructure
# 69  revision  power_1138_bus  power-1138-bus  infrastructure
# 70  revision  power_1138_bus  power-1138-bus  infrastructure
# 71  revision  power_1138_bus  power-1138-bus  infrastructure
#
#               family method_id method  average_precision_mean  \
# 0   local_similarity        cn     CN                0.992351
# 1   local_similarity        aa     AA                0.993538
# 2   local_similarity        ra     RA                0.995063
# 3   local_similarity        ja     JA                0.989453
# 4   local_similarity        sa     SA                0.990159
# ..               ...       ...    ...                     ...
# 67  local_similarity        sa     SA                0.778859
# 68  local_similarity        so     SO                0.778859
# 69  local_similarity       hpi    HPI                0.778859
# 70  local_similarity       hdi    HDI                0.778859
# 71  local_similarity      llhn   LLHN                0.778859
#
#     average_precision_std  roc_auc_mean  roc_auc_std  precision_mean  \
# 0                0.000599      0.992723     0.000542        0.971151
# 1                0.000553      0.993757     0.000498        0.974844
# 2                0.000364      0.994788     0.000456        0.976864
# 3                0.001014      0.990458     0.000539        0.954927
# 4                0.001031      0.991451     0.000520        0.961423
# ..                    ...           ...          ...             ...
# 67               0.041508      0.702548     0.035283        0.635721
# 68               0.041508      0.702548     0.035283        0.635721
# 69               0.041508      0.702548     0.035283        0.635721
# 70               0.041508      0.702548     0.035283        0.635721
# 71               0.041508      0.702548     0.035283        0.635721
#
#     precision_std  recall_mean  recall_std   f1_mean    f1_std  ndcg_mean  \
# 0        0.001484     0.971151    0.001484  0.971151  0.001484   0.974091
# 1        0.001339     0.974844    0.001339  0.974844  0.001339   0.977423
# 2        0.001412     0.976864    0.001412  0.976864  0.001412   0.979350
# 3        0.001471     0.954927    0.001471  0.954927  0.001471   0.959260
# 4        0.000988     0.961423    0.000988  0.961423  0.000988   0.964965
# ..            ...          ...         ...       ...       ...        ...
# 67       0.051459     0.635721    0.051459  0.635721  0.051459   0.720972
# 68       0.051459     0.635721    0.051459  0.635721  0.051459   0.720972
# 69       0.051459     0.635721    0.051459  0.635721  0.051459   0.720972
# 70       0.051459     0.635721    0.051459  0.635721  0.051459   0.720972
# 71       0.051459     0.635721    0.051459  0.635721  0.051459   0.720972
#
#     ndcg_std
# 0   0.001336
# 1   0.001203
# 2   0.001260
# 3   0.001458
# 4   0.001124
# ..       ...
# 67  0.042991
# 68  0.042991
# 69  0.042991
# 70  0.042991
# 71  0.042991
#
# [72 rows x 19 columns]
