# %%
from link_prediction.evaluation import (
    run_method_family_benchmark,
)

from link_prediction.methods.enhanced_local import (
    score_enhanced_local_candidates,
)

# %%
fold_metrics, network_summary = (
    run_method_family_benchmark(
        family_id="enhanced_local",
        scorer=score_enhanced_local_candidates,
        benchmark_name="revision",
    )
)

fold_metrics
# Out:
#     benchmark      network_id         network          domain  fold  \
# 0    revision    ego_facebook    ego-Facebook          social     1
# 1    revision    ego_facebook    ego-Facebook          social     1
# 2    revision    ego_facebook    ego-Facebook          social     1
# 3    revision    ego_facebook    ego-Facebook          social     1
# 4    revision    ego_facebook    ego-Facebook          social     2
# ..        ...             ...             ...             ...   ...
# 155  revision  power_1138_bus  power-1138-bus  infrastructure     4
# 156  revision  power_1138_bus  power-1138-bus  infrastructure     5
# 157  revision  power_1138_bus  power-1138-bus  infrastructure     5
# 158  revision  power_1138_bus  power-1138-bus  infrastructure     5
# 159  revision  power_1138_bus  power-1138-bus  infrastructure     5
#
#              family method_id  average_precision   roc_auc  precision  \
# 0    enhanced_local    ra_cni           0.988901  0.990312   0.952732
# 1    enhanced_local       ia2           0.992710  0.993674   0.976188
# 2    enhanced_local    car_ra           0.982446  0.983281   0.971853
# 3    enhanced_local       fsw           0.991131  0.992361   0.970546
# 4    enhanced_local    ra_cni           0.989588  0.990869   0.954154
# ..              ...       ...                ...       ...        ...
# 155  enhanced_local       fsw           0.710938  0.710938   0.671875
# 156  enhanced_local    ra_cni           0.742188  0.742188   0.671875
# 157  enhanced_local       ia2           0.664062  0.664062   0.593750
# 158  enhanced_local    car_ra           0.507812  0.507812   0.484375
# 159  enhanced_local       fsw           0.664062  0.664062   0.593750
#
#        recall        f1      ndcg  cutoff  positive_count  negative_count  \
# 0    0.952732  0.952732  0.957602   16840           16840           16840
# 1    0.976188  0.976188  0.978594   16840           16840           16840
# 2    0.971853  0.971853  0.974754   16840           16840           16840
# 3    0.970546  0.970546  0.973538   16840           16840           16840
# 4    0.954154  0.954154  0.958906   16839           16839           16839
# ..        ...       ...       ...     ...             ...             ...
# 155  0.671875  0.671875  0.753392      64              64              64
# 156  0.671875  0.671875  0.754895      64              64              64
# 157  0.593750  0.593750  0.685342      64              64              64
# 158  0.484375  0.484375  0.531993      64              64              64
# 159  0.593750  0.593750  0.685342      64              64              64
#
#      candidate_count  method  family_scoring_seconds
# 0              33680  RA-CNI               50.145337
# 1              33680     IA2               50.145337
# 2              33680  CAR-RA               50.145337
# 3              33680     FSW               50.145337
# 4              33678  RA-CNI               49.217315
# ..               ...     ...                     ...
# 155              128     FSW                0.002012
# 156              128  RA-CNI                0.001943
# 157              128     IA2                0.001943
# 158              128  CAR-RA                0.001943
# 159              128     FSW                0.001943
#
# [160 rows x 19 columns]

# %%
network_summary
# Out:
#    benchmark          network_id             network  \
# 0   revision        ego_facebook        ego-Facebook
# 1   revision        ego_facebook        ego-Facebook
# 2   revision        ego_facebook        ego-Facebook
# 3   revision        ego_facebook        ego-Facebook
# 4   revision  socfb_middlebury45  socfb-Middlebury45
# 5   revision  socfb_middlebury45  socfb-Middlebury45
# 6   revision  socfb_middlebury45  socfb-Middlebury45
# 7   revision  socfb_middlebury45  socfb-Middlebury45
# 8   revision             ca_grqc             ca-GrQc
# 9   revision             ca_grqc             ca-GrQc
# 10  revision             ca_grqc             ca-GrQc
# 11  revision             ca_grqc             ca-GrQc
# 12  revision            ca_hepth            ca-HepTh
# 13  revision            ca_hepth            ca-HepTh
# 14  revision            ca_hepth            ca-HepTh
# 15  revision            ca_hepth            ca-HepTh
# 16  revision       email_eu_core       email-Eu-core
# 17  revision       email_eu_core       email-Eu-core
# 18  revision       email_eu_core       email-Eu-core
# 19  revision       email_eu_core       email-Eu-core
# 20  revision          email_univ          email-univ
# 21  revision          email_univ          email-univ
# 22  revision          email_univ          email-univ
# 23  revision          email_univ          email-univ
# 24  revision          power_grid          power-grid
# 25  revision          power_grid          power-grid
# 26  revision          power_grid          power-grid
# 27  revision          power_grid          power-grid
# 28  revision      power_1138_bus      power-1138-bus
# 29  revision      power_1138_bus      power-1138-bus
# 30  revision      power_1138_bus      power-1138-bus
# 31  revision      power_1138_bus      power-1138-bus
#
#                       domain          family method_id  method  \
# 0                     social  enhanced_local    ra_cni  RA-CNI
# 1                     social  enhanced_local       ia2     IA2
# 2                     social  enhanced_local    car_ra  CAR-RA
# 3                     social  enhanced_local       fsw     FSW
# 4                     social  enhanced_local    ra_cni  RA-CNI
# 5                     social  enhanced_local       ia2     IA2
# 6                     social  enhanced_local    car_ra  CAR-RA
# 7                     social  enhanced_local       fsw     FSW
# 8   scientific_collaboration  enhanced_local    ra_cni  RA-CNI
# 9   scientific_collaboration  enhanced_local       ia2     IA2
# 10  scientific_collaboration  enhanced_local    car_ra  CAR-RA
# 11  scientific_collaboration  enhanced_local       fsw     FSW
# 12  scientific_collaboration  enhanced_local    ra_cni  RA-CNI
# 13  scientific_collaboration  enhanced_local       ia2     IA2
# 14  scientific_collaboration  enhanced_local    car_ra  CAR-RA
# 15  scientific_collaboration  enhanced_local       fsw     FSW
# 16             communication  enhanced_local    ra_cni  RA-CNI
# 17             communication  enhanced_local       ia2     IA2
# 18             communication  enhanced_local    car_ra  CAR-RA
# 19             communication  enhanced_local       fsw     FSW
# 20             communication  enhanced_local    ra_cni  RA-CNI
# 21             communication  enhanced_local       ia2     IA2
# 22             communication  enhanced_local    car_ra  CAR-RA
# 23             communication  enhanced_local       fsw     FSW
# 24            infrastructure  enhanced_local    ra_cni  RA-CNI
# 25            infrastructure  enhanced_local       ia2     IA2
# 26            infrastructure  enhanced_local    car_ra  CAR-RA
# 27            infrastructure  enhanced_local       fsw     FSW
# 28            infrastructure  enhanced_local    ra_cni  RA-CNI
# 29            infrastructure  enhanced_local       ia2     IA2
# 30            infrastructure  enhanced_local    car_ra  CAR-RA
# 31            infrastructure  enhanced_local       fsw     FSW
#
#     average_precision_mean  average_precision_std  roc_auc_mean  roc_auc_std  \
# 0                 0.989160               0.000707      0.990545     0.000618
# 1                 0.993504               0.000568      0.994227     0.000479
# 2                 0.982843               0.000509      0.983389     0.000504
# 3                 0.992110               0.000675      0.993038     0.000545
# 4                 0.917687               0.000936      0.927813     0.000656
# 5                 0.954398               0.001003      0.956233     0.001059
# 6                 0.943402               0.000825      0.944287     0.000920
# 7                 0.952901               0.001182      0.954762     0.000981
# 8                 0.981600               0.003176      0.981506     0.003099
# 9                 0.966692               0.003709      0.966584     0.003736
# 10                0.850656               0.008662      0.850525     0.008582
# 11                0.966184               0.003680      0.966223     0.003709
# 12                0.967420               0.001821      0.967066     0.001867
# 13                0.936412               0.002624      0.936409     0.002585
# 14                0.740515               0.003860      0.740460     0.003897
# 15                0.935985               0.002572      0.936190     0.002558
# 16                0.929816               0.002983      0.937139     0.002796
# 17                0.950672               0.002246      0.951410     0.002299
# 18                0.930361               0.002388      0.929828     0.002242
# 19                0.939924               0.001843      0.941794     0.001361
# 20                0.928411               0.002980      0.926496     0.004087
# 21                0.855203               0.004137      0.855664     0.003532
# 22                0.692197               0.011911      0.691792     0.012484
# 23                0.854811               0.003956      0.854299     0.003538
