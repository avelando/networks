# %%
from link_prediction.evaluation import (
    run_method_family_benchmark,
)

from link_prediction.methods.enhanced_local import (
    score_enhanced_local_candidates,
)

# %%
fold_metrics, network_summary = (
    run_method_family_benchmark(
        family_id="enhanced_local",
        scorer=score_enhanced_local_candidates,
        benchmark_name="standard",
    )
)

fold_metrics
# Out:
# enhanced_local: 40 tasks, 6 workers
#     benchmark      network_id         network          domain  fold  \
# 0    standard    ego_facebook    ego-Facebook          social     1
# 1    standard    ego_facebook    ego-Facebook          social     1
# 2    standard    ego_facebook    ego-Facebook          social     1
# 3    standard    ego_facebook    ego-Facebook          social     1
# 4    standard    ego_facebook    ego-Facebook          social     1
# ..        ...             ...             ...             ...   ...
# 315  standard  power_1138_bus  power-1138-bus  infrastructure     5
# 316  standard  power_1138_bus  power-1138-bus  infrastructure     5
# 317  standard  power_1138_bus  power-1138-bus  infrastructure     5
# 318  standard  power_1138_bus  power-1138-bus  infrastructure     5
# 319  standard  power_1138_bus  power-1138-bus  infrastructure     5
#
#              family method_id  average_precision   roc_auc  precision  ...  \
# 0    enhanced_local    ra_cni           0.988901  0.990312   0.952732  ...
# 1    enhanced_local       ia1           0.992747  0.993711   0.975594  ...
# 2    enhanced_local       ia2           0.992710  0.993674   0.976188  ...
# 3    enhanced_local    car_cn           0.980930  0.982273   0.970368  ...
# 4    enhanced_local    car_aa           0.981326  0.982525   0.972090  ...
# ..              ...       ...                ...       ...        ...  ...
# 315  enhanced_local    car_cn           0.507812  0.507812   0.484375  ...
# 316  enhanced_local    car_aa           0.507812  0.507812   0.484375  ...
# 317  enhanced_local    car_ra           0.507812  0.507812   0.484375  ...
# 318  enhanced_local       fsw           0.664062  0.664062   0.593750  ...
# 319  enhanced_local       lit           0.570312  0.570312   0.515625  ...
#
#      tied_candidate_ratio  largest_tie_group  cutoff_score  cutoff_tie_size  \
# 0                0.407185              11715      1.850149                1
# 1                0.499852              14740      0.098262                1
# 2                0.500148              14740      0.049137                2
# 3                0.832957              16725      2.000000              368
# 4                0.506829              16725      0.396939                1
# ..                    ...                ...           ...              ...
# 315              0.992188                127      0.000000              127
# 316              0.992188                127      0.000000              127
# 317              0.992188                127      0.000000              127
# 318              0.929688                107      0.000000              107
# 319              0.929688                119      0.000000              119
#
#      cutoff_tie_positive_count  cutoff_tie_negative_count  \
# 0                            0                          1
# 1                            1                          0
# 2                            0                          2
# 3                          196                        172
# 4                            0                          1
# ..                         ...                        ...
# 315                         63                         64
# 316                         63                         64
# 317                         63                         64
# 318                         43                         64
# 319                         55                         64
#
#      cutoff_slots_in_tie  cutoff_tie_crosses_boundary  method  \
# 0                      1                        False  RA-CNI
# 1                      1                        False     IA1
# 2                      2                        False     IA2
# 3                    253                         True  CAR-CN
# 4                      1                        False  CAR-AA
# ..                   ...                          ...     ...
# 315                   63                         True  CAR-CN
# 316                   63                         True  CAR-AA
# 317                   63                         True  CAR-RA
# 318                   43                         True     FSW
# 319                   55                         True  LIT-i2
#
#      family_scoring_seconds
# 0                154.475292
# 1                154.475292
# 2                154.475292
# 3                154.475292
# 4                154.475292
# ..                      ...
# 315                0.028164
# 316                0.028164
# 317                0.028164
# 318                0.028164
# 319                0.028164
#
# [320 rows x 30 columns]

# %%
network_summary
# Out:
#    benchmark      network_id         network          domain          family  \
# 0   standard    ego_facebook    ego-Facebook          social  enhanced_local
# 1   standard    ego_facebook    ego-Facebook          social  enhanced_local
# 2   standard    ego_facebook    ego-Facebook          social  enhanced_local
# 3   standard    ego_facebook    ego-Facebook          social  enhanced_local
# 4   standard    ego_facebook    ego-Facebook          social  enhanced_local
# ..       ...             ...             ...             ...             ...
# 59  standard  power_1138_bus  power-1138-bus  infrastructure  enhanced_local
# 60  standard  power_1138_bus  power-1138-bus  infrastructure  enhanced_local
# 61  standard  power_1138_bus  power-1138-bus  infrastructure  enhanced_local
# 62  standard  power_1138_bus  power-1138-bus  infrastructure  enhanced_local
# 63  standard  power_1138_bus  power-1138-bus  infrastructure  enhanced_local
#
#    method_id  method  average_precision_mean  average_precision_std  \
# 0     ra_cni  RA-CNI                0.989160               0.000707
# 1        ia1     IA1                0.993548               0.000574
# 2        ia2     IA2                0.993504               0.000568
# 3     car_cn  CAR-CN                0.981384               0.000512
# 4     car_aa  CAR-AA                0.981805               0.000506
# ..       ...     ...                     ...                    ...
# 59    car_cn  CAR-CN                0.510913               0.004301
# 60    car_aa  CAR-AA                0.510913               0.004301
# 61    car_ra  CAR-RA                0.510913               0.004301
# 62       fsw     FSW                0.702548               0.035283
# 63       lit  LIT-i2                0.591899               0.030447
#
#     roc_auc_mean  ...  cutoff_tie_size_mean  cutoff_tie_size_std  \
# 0       0.990545  ...                   1.0             0.000000
# 1       0.994264  ...                   1.0             0.000000
# 2       0.994227  ...                   2.0             1.224745
# 3       0.982402  ...                 403.6            37.799471
# 4       0.982661  ...                   2.8             2.489980
# ..           ...  ...                   ...                  ...
# 59      0.510913  ...                 127.0             1.224745
# 60      0.510913  ...                 127.0             1.224745
# 61      0.510913  ...                 127.0             1.224745
# 62      0.702548  ...                 102.4             4.774935
# 63      0.591899  ...                 116.6             3.974921
#
#     cutoff_tie_positive_count_mean  cutoff_tie_positive_count_std  \
# 0                              0.2                       0.447214
# 1                              0.6                       0.547723
# 2                              1.0                       1.224745
# 3                            227.2                      34.924204
# 4                              0.8                       0.836660
# ..                             ...                            ...
# 59                            62.8                       0.836660
# 60                            62.8                       0.836660
# 61                            62.8                       0.836660
# 62                            38.2                       4.604346
# 63                            52.4                       3.911521
#
#     cutoff_tie_negative_count_mean  cutoff_tie_negative_count_std  \
# 0                              0.8                       0.447214
# 1                              0.4                       0.547723
# 2                              1.0                       0.707107
# 3                            176.4                      16.920402
# 4                              2.0                       2.236068
# ..                             ...                            ...
# 59                            64.2                       0.447214
# 60                            64.2                       0.447214
# 61                            64.2                       0.447214
# 62                            64.2                       0.447214
# 63                            64.2                       0.447214
#
#     cutoff_slots_in_tie_mean  cutoff_slots_in_tie_std  \
# 0                        1.0                 0.000000
# 1                        1.0                 0.000000
# 2                        1.4                 0.547723
# 3                      300.8                66.330234
# 4                        2.0                 1.732051
# ..                       ...                      ...
# 59                      62.8                 0.836660
# 60                      62.8                 0.836660
# 61                      62.8                 0.836660
# 62                      38.2                 4.604346
# 63                      52.4                 3.911521
#
#     cutoff_tie_crosses_boundary_mean  cutoff_tie_crosses_boundary_std
# 0                                0.0                         0.000000
# 1                                0.0                         0.000000
# 2                                0.4                         0.547723
# 3                                1.0                         0.000000
# 4                                0.4                         0.547723
# ..                               ...                              ...
# 59                               1.0                         0.000000
# 60                               1.0                         0.000000
# 61                               1.0                         0.000000
# 62                               1.0                         0.000000
# 63                               1.0                         0.000000
#
# [64 rows x 39 columns]
