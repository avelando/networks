# %%
from link_prediction.evaluation import (
    run_method_family_benchmark,
)

from link_prediction.methods.local_bayesian import (
    score_local_bayesian_candidates,
)

# %%
fold_metrics, network_summary = (
    run_method_family_benchmark(
        family_id="local_bayesian",
        scorer=score_local_bayesian_candidates,
        benchmark_name="standard",
    )
)

fold_metrics
# Out:
# local_bayesian: 40 tasks, 6 workers
#     benchmark      network_id         network          domain  fold  \
# 0    standard    ego_facebook    ego-Facebook          social     1
# 1    standard    ego_facebook    ego-Facebook          social     1
# 2    standard    ego_facebook    ego-Facebook          social     1
# 3    standard    ego_facebook    ego-Facebook          social     2
# 4    standard    ego_facebook    ego-Facebook          social     2
# ..        ...             ...             ...             ...   ...
# 115  standard  power_1138_bus  power-1138-bus  infrastructure     4
# 116  standard  power_1138_bus  power-1138-bus  infrastructure     4
# 117  standard  power_1138_bus  power-1138-bus  infrastructure     5
# 118  standard  power_1138_bus  power-1138-bus  infrastructure     5
# 119  standard  power_1138_bus  power-1138-bus  infrastructure     5
#
#              family method_id  average_precision   roc_auc  precision  ...  \
# 0    local_bayesian    lnb_cn           0.990982  0.992356   0.972031  ...
# 1    local_bayesian    lnb_aa           0.991902  0.993053   0.974466  ...
# 2    local_bayesian    lnb_ra           0.993838  0.994267   0.976010  ...
# 3    local_bayesian    lnb_cn           0.992251  0.993178   0.972089  ...
# 4    local_bayesian    lnb_aa           0.993096  0.993836   0.974880  ...
# ..              ...       ...                ...       ...        ...  ...
# 115  local_bayesian    lnb_aa           0.710938  0.710938   0.671875  ...
# 116  local_bayesian    lnb_ra           0.710938  0.710938   0.671875  ...
# 117  local_bayesian    lnb_cn           0.664062  0.664062   0.593750  ...
# 118  local_bayesian    lnb_aa           0.664062  0.664062   0.593750  ...
# 119  local_bayesian    lnb_ra           0.664062  0.664062   0.593750  ...
#
#      tied_candidate_ratio  largest_tie_group  cutoff_score  cutoff_tie_size  \
# 0                0.493943              14740      6.329970                1
# 1                0.493824              14740      1.701423                1
# 2                0.493824              14740      0.131240                1
# 3                0.495843              14799      5.982718                1
# 4                0.495784              14799      1.544935                1
# ..                    ...                ...           ...              ...
# 115              0.898438                101      0.000000              101
# 116              0.898438                101      0.000000              101
# 117              0.914062                107      0.000000              107
# 118              0.914062                107      0.000000              107
# 119              0.914062                107      0.000000              107
#
#      cutoff_tie_positive_count  cutoff_tie_negative_count  \
# 0                            0                          1
# 1                            1                          0
# 2                            0                          1
# 3                            0                          1
# 4                            1                          0
# ..                         ...                        ...
# 115                         37                         64
# 116                         37                         64
# 117                         43                         64
# 118                         43                         64
# 119                         43                         64
#
#      cutoff_slots_in_tie  cutoff_tie_crosses_boundary  method  \
# 0                      1                        False  LNB-CN
# 1                      1                        False  LNB-AA
# 2                      1                        False  LNB-RA
# 3                      1                        False  LNB-CN
# 4                      1                        False  LNB-AA
# ..                   ...                          ...     ...
# 115                   37                         True  LNB-AA
# 116                   37                         True  LNB-RA
# 117                   43                         True  LNB-CN
# 118                   43                         True  LNB-AA
# 119                   43                         True  LNB-RA
#
#      family_scoring_seconds
# 0                  1.555505
# 1                  1.555505
# 2                  1.555505
# 3                  1.650589
# 4                  1.650589
# ..                      ...
# 115                0.008265
# 116                0.008265
# 117                0.007845
# 118                0.007845
# 119                0.007845
#
# [120 rows x 30 columns]

# %%
network_summary
# Out:
#    benchmark          network_id             network  \
# 0   standard        ego_facebook        ego-Facebook
# 1   standard        ego_facebook        ego-Facebook
# 2   standard        ego_facebook        ego-Facebook
# 3   standard  socfb_middlebury45  socfb-Middlebury45
# 4   standard  socfb_middlebury45  socfb-Middlebury45
# 5   standard  socfb_middlebury45  socfb-Middlebury45
# 6   standard             ca_grqc             ca-GrQc
# 7   standard             ca_grqc             ca-GrQc
# 8   standard             ca_grqc             ca-GrQc
# 9   standard            ca_hepth            ca-HepTh
# 10  standard            ca_hepth            ca-HepTh
# 11  standard            ca_hepth            ca-HepTh
# 12  standard       email_eu_core       email-Eu-core
# 13  standard       email_eu_core       email-Eu-core
# 14  standard       email_eu_core       email-Eu-core
# 15  standard          email_univ          email-univ
# 16  standard          email_univ          email-univ
# 17  standard          email_univ          email-univ
# 18  standard          power_grid          power-grid
# 19  standard          power_grid          power-grid
# 20  standard          power_grid          power-grid
# 21  standard      power_1138_bus      power-1138-bus
# 22  standard      power_1138_bus      power-1138-bus
# 23  standard      power_1138_bus      power-1138-bus
#
#                       domain          family method_id  method  \
# 0                     social  local_bayesian    lnb_cn  LNB-CN
# 1                     social  local_bayesian    lnb_aa  LNB-AA
# 2                     social  local_bayesian    lnb_ra  LNB-RA
# 3                     social  local_bayesian    lnb_cn  LNB-CN
# 4                     social  local_bayesian    lnb_aa  LNB-AA
# 5                     social  local_bayesian    lnb_ra  LNB-RA
# 6   scientific_collaboration  local_bayesian    lnb_cn  LNB-CN
# 7   scientific_collaboration  local_bayesian    lnb_aa  LNB-AA
# 8   scientific_collaboration  local_bayesian    lnb_ra  LNB-RA
# 9   scientific_collaboration  local_bayesian    lnb_cn  LNB-CN
# 10  scientific_collaboration  local_bayesian    lnb_aa  LNB-AA
# 11  scientific_collaboration  local_bayesian    lnb_ra  LNB-RA
# 12             communication  local_bayesian    lnb_cn  LNB-CN
# 13             communication  local_bayesian    lnb_aa  LNB-AA
# 14             communication  local_bayesian    lnb_ra  LNB-RA
# 15             communication  local_bayesian    lnb_cn  LNB-CN
# 16             communication  local_bayesian    lnb_aa  LNB-AA
# 17             communication  local_bayesian    lnb_ra  LNB-RA
# 18            infrastructure  local_bayesian    lnb_cn  LNB-CN
# 19            infrastructure  local_bayesian    lnb_aa  LNB-AA
# 20            infrastructure  local_bayesian    lnb_ra  LNB-RA
# 21            infrastructure  local_bayesian    lnb_cn  LNB-CN
# 22            infrastructure  local_bayesian    lnb_aa  LNB-AA
# 23            infrastructure  local_bayesian    lnb_ra  LNB-RA
#
#     average_precision_mean  average_precision_std  roc_auc_mean  ...  \
# 0                 0.991912               0.000677      0.992983  ...
# 1                 0.992781               0.000645      0.993660  ...
# 2                 0.994363               0.000457      0.994741  ...
# 3                 0.948795               0.000698      0.952235  ...
# 4                 0.951215               0.000779      0.954281  ...
# 5                 0.954206               0.001189      0.956644  ...
# 6                 0.966353               0.003914      0.966321  ...
# 7                 0.966671               0.003766      0.966557  ...
# 8                 0.966753               0.003695      0.966622  ...
# 9                 0.936391               0.002611      0.936390  ...
# 10                0.936556               0.002583      0.936489  ...
# 11                0.936528               0.002610      0.936471  ...
# 12                0.945731               0.002193      0.948265  ...
# 13                0.949201               0.002101      0.950898  ...
# 14                0.951720               0.002067      0.952725  ...
# 15                0.858974               0.002420      0.856985  ...
# 16                0.860219               0.002368      0.857622  ...
# 17                0.859710               0.002765      0.857445  ...
# 18                0.680959               0.013224      0.681168  ...
# 19                0.681190               0.013218      0.681228  ...
# 20                0.681044               0.013229      0.681208  ...
# 21                0.702548               0.035283      0.702548  ...
# 22                0.702548               0.035283      0.702548  ...
# 23                0.702548               0.035283      0.702548  ...
#
#     cutoff_tie_size_mean  cutoff_tie_size_std  cutoff_tie_positive_count_mean  \
# 0                    1.4             0.547723                             0.8
# 1                    1.2             0.447214                             1.0
# 2                    1.0             0.000000                             0.8
# 3                    1.0             0.000000                             0.4
# 4                    1.0             0.000000                             0.6
# 5                    1.0             0.000000                             0.4
# 6                 1964.0            10.770330                           121.6
# 7                 1964.0            10.770330                           121.6
# 8                 1964.0            10.770330                           121.6
# 9                 3631.2            16.961722                           407.2
# 10                3631.2            16.961722                           407.2
# 11                3631.2            16.961722                           407.2
# 12                   1.0             0.000000                             0.6
# 13                   1.0             0.000000                             0.0
# 14                   1.0             0.000000                             0.6
# 15                1022.2             9.284396                           216.0
# 16                1022.2             9.284396                           216.0
# 17                1022.2             9.284396                           216.0
# 18                 540.2             7.694154                           210.2
# 19                 540.2             7.694154                           210.2
# 20                 540.2             7.694154                           210.2
# 21                 102.4             4.774935                            38.2
# 22                 102.4             4.774935                            38.2
# 23                 102.4             4.774935                            38.2
#
#     cutoff_tie_positive_count_std  cutoff_tie_negative_count_mean  \
# 0                        0.836660                             0.6
# 1                        0.707107                             0.2
# 2                        0.447214                             0.2
# 3                        0.547723                             0.6
# 4                        0.547723                             0.4
# 5                        0.547723                             0.6
# 6                       13.049904                          1842.4
# 7                       13.049904                          1842.4
# 8                       13.049904                          1842.4
# 9                       16.528763                          3224.0
# 10                      16.528763                          3224.0
# 11                      16.528763                          3224.0
# 12                       0.547723                             0.4
# 13                       0.000000                             1.0
# 14                       0.547723                             0.4
# 15                       4.847680                           806.2
# 16                       4.847680                           806.2
# 17                       4.847680                           806.2
# 18                       8.167007                           330.0
# 19                       8.167007                           330.0
# 20                       8.167007                           330.0
# 21                       4.604346                            64.2
# 22                       4.604346                            64.2
# 23                       4.604346                            64.2
#
#     cutoff_tie_negative_count_std  cutoff_slots_in_tie_mean  \
# 0                        0.547723                       1.2
# 1                        0.447214                       1.2
# 2                        0.447214                       1.0
# 3                        0.547723                       1.0
# 4                        0.547723                       1.0
# 5                        0.547723                       1.0
# 6                        3.911521                     111.0
# 7                        3.911521                     111.0
# 8                        3.911521                     111.0
# 9                        1.224745                     397.4
# 10                       1.224745                     397.4
# 11                       1.224745                     397.4
# 12                       0.547723                       1.0
# 13                       0.000000                       1.0
# 14                       0.547723                       1.0
# 15                       6.870226                     158.8
# 16                       6.870226                     158.8
# 17                       6.870226                     158.8
# 18                       0.707107                     209.4
# 19                       0.707107                     209.4
# 20                       0.707107                     209.4
# 21                       0.447214                      38.2
# 22                       0.447214                      38.2
# 23                       0.447214                      38.2
#
#     cutoff_slots_in_tie_std  cutoff_tie_crosses_boundary_mean  \
# 0                  0.447214                               0.2
# 1                  0.447214                               0.0
# 2                  0.000000                               0.0
# 3                  0.000000                               0.0
# 4                  0.000000                               0.0
# 5                  0.000000                               0.0
# 6                 10.770330                               1.0
# 7                 10.770330                               1.0
# 8                 10.770330                               1.0
# 9                 17.126004                               1.0
# 10                17.126004                               1.0
# 11                17.126004                               1.0
# 12                 0.000000                               0.0
# 13                 0.000000                               0.0
# 14                 0.000000                               0.0
# 15                 9.038805                               1.0
# 16                 9.038805                               1.0
# 17                 9.038805                               1.0
# 18                 7.987490                               1.0
# 19                 7.987490                               1.0
# 20                 7.987490                               1.0
# 21                 4.604346                               1.0
# 22                 4.604346                               1.0
# 23                 4.604346                               1.0
#
#     cutoff_tie_crosses_boundary_std
# 0                          0.447214
# 1                          0.000000
# 2                          0.000000
# 3                          0.000000
# 4                          0.000000
# 5                          0.000000
# 6                          0.000000
# 7                          0.000000
# 8                          0.000000
# 9                          0.000000
# 10                         0.000000
# 11                         0.000000
# 12                         0.000000
# 13                         0.000000
# 14                         0.000000
# 15                         0.000000
# 16                         0.000000
# 17                         0.000000
# 18                         0.000000
# 19                         0.000000
# 20                         0.000000
# 21                         0.000000
# 22                         0.000000
# 23                         0.000000
#
# [24 rows x 39 columns]
