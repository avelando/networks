# %%
from functools import partial

from link_prediction.config import (
    load_methods_config,
)
from link_prediction.evaluation import (
    run_method_family_benchmark,
)
from link_prediction.methods.quasi_local_paths import (
    score_quasi_local_path_candidates,
)

# %%
method_config = (
    load_methods_config()[
        "methods"
    ][
        "lpi"
    ]
)

lpi_scorer = partial(
    score_quasi_local_path_candidates,
    **method_config["parameters"],
)

fold_metrics, network_summary = (
    run_method_family_benchmark(
        family_id="quasi_local_path",
        scorer=lpi_scorer,
        benchmark_name="revision",
    )
)

fold_metrics
# Out:
#    benchmark          network_id             network  \
# 0   revision        ego_facebook        ego-Facebook
# 1   revision        ego_facebook        ego-Facebook
# 2   revision        ego_facebook        ego-Facebook
# 3   revision        ego_facebook        ego-Facebook
# 4   revision        ego_facebook        ego-Facebook
# 5   revision  socfb_middlebury45  socfb-Middlebury45
# 6   revision  socfb_middlebury45  socfb-Middlebury45
# 7   revision  socfb_middlebury45  socfb-Middlebury45
# 8   revision  socfb_middlebury45  socfb-Middlebury45
# 9   revision  socfb_middlebury45  socfb-Middlebury45
# 10  revision             ca_grqc             ca-GrQc
# 11  revision             ca_grqc             ca-GrQc
# 12  revision             ca_grqc             ca-GrQc
# 13  revision             ca_grqc             ca-GrQc
# 14  revision             ca_grqc             ca-GrQc
# 15  revision            ca_hepth            ca-HepTh
# 16  revision            ca_hepth            ca-HepTh
# 17  revision            ca_hepth            ca-HepTh
# 18  revision            ca_hepth            ca-HepTh
# 19  revision            ca_hepth            ca-HepTh
# 20  revision       email_eu_core       email-Eu-core
# 21  revision       email_eu_core       email-Eu-core
# 22  revision       email_eu_core       email-Eu-core
# 23  revision       email_eu_core       email-Eu-core
# 24  revision       email_eu_core       email-Eu-core
# 25  revision          email_univ          email-univ
# 26  revision          email_univ          email-univ
# 27  revision          email_univ          email-univ
# 28  revision          email_univ          email-univ
# 29  revision          email_univ          email-univ
# 30  revision          power_grid          power-grid
# 31  revision          power_grid          power-grid
# 32  revision          power_grid          power-grid
# 33  revision          power_grid          power-grid
# 34  revision          power_grid          power-grid
# 35  revision      power_1138_bus      power-1138-bus
# 36  revision      power_1138_bus      power-1138-bus
# 37  revision      power_1138_bus      power-1138-bus
# 38  revision      power_1138_bus      power-1138-bus
# 39  revision      power_1138_bus      power-1138-bus
#
#                       domain  fold            family method_id  \
# 0                     social     1  quasi_local_path       lpi
# 1                     social     2  quasi_local_path       lpi
# 2                     social     3  quasi_local_path       lpi
# 3                     social     4  quasi_local_path       lpi
# 4                     social     5  quasi_local_path       lpi
# 5                     social     1  quasi_local_path       lpi
# 6                     social     2  quasi_local_path       lpi
# 7                     social     3  quasi_local_path       lpi
# 8                     social     4  quasi_local_path       lpi
# 9                     social     5  quasi_local_path       lpi
# 10  scientific_collaboration     1  quasi_local_path       lpi
# 11  scientific_collaboration     2  quasi_local_path       lpi
# 12  scientific_collaboration     3  quasi_local_path       lpi
# 13  scientific_collaboration     4  quasi_local_path       lpi
# 14  scientific_collaboration     5  quasi_local_path       lpi
# 0                 0.478632
# 1                 0.469201
# 2                 0.461375
# 3                 0.461341
# 4                 0.455858
# 5                 1.614762
# 6                 1.506309
# 7                 1.744227
# 8                 1.420670
# 9                 1.413932
# 10                0.026649
# 11                0.027458
# 12                0.027287
# 13                0.026624
# 14                0.028097
# 15                0.072381
# 16                0.070974
# 17                0.070667
# 18                0.069679
# 19                0.070043
# 20                0.081068
# 21                0.080203
# 22                0.078675
# 23                0.116197
# 24                0.078744
# 25                0.018466
# 26                0.018352
# 27                0.018445
# 28                0.018753
# 29                0.018619
# 30                0.010864
# 31                0.010456
# 32                0.010789
# 33                0.010112
# 34                0.010111
# 35                0.002576
# 36                0.002568
# 37                0.002560
# 38                0.002573
# 39                0.002571

# %%
network_summary
# Out:
#   benchmark          network_id             network                    domain  \
# 0  revision        ego_facebook        ego-Facebook                    social
# 1  revision  socfb_middlebury45  socfb-Middlebury45                    social
# 2  revision             ca_grqc             ca-GrQc  scientific_collaboration
# 3  revision            ca_hepth            ca-HepTh  scientific_collaboration
# 4  revision       email_eu_core       email-Eu-core             communication
# 5  revision          email_univ          email-univ             communication
# 6  revision          power_grid          power-grid            infrastructure
# 7  revision      power_1138_bus      power-1138-bus            infrastructure
#
#              family method_id          method  average_precision_mean  \
# 0  quasi_local_path       lpi  LPI-beta-0.001                0.992683
# 1  quasi_local_path       lpi  LPI-beta-0.001                0.946743
# 2  quasi_local_path       lpi  LPI-beta-0.001                0.988119
# 3  quasi_local_path       lpi  LPI-beta-0.001                0.978964
# 4  quasi_local_path       lpi  LPI-beta-0.001                0.943240
# 5  quasi_local_path       lpi  LPI-beta-0.001                0.936512
# 6  quasi_local_path       lpi  LPI-beta-0.001                0.837039
# 7  quasi_local_path       lpi  LPI-beta-0.001                0.868947
#
#    average_precision_std  roc_auc_mean  roc_auc_std  precision_mean  \
# 0               0.000597      0.993818     0.000448        0.968300
# 1               0.000517      0.950232     0.000698        0.881264
# 2               0.002535      0.981986     0.003128        0.967620
# 3               0.001325      0.967725     0.001920        0.941616
# 4               0.002203      0.947013     0.001592        0.876517
# 5               0.004458      0.929138     0.006493        0.868488
# 6               0.011124      0.770922     0.010701        0.678330
# 7               0.036457      0.812788     0.036769        0.753990
#
#    precision_std  recall_mean  recall_std   f1_mean    f1_std  ndcg_mean  \
# 0       0.001496     0.968300    0.001496  0.968300  0.001496   0.971556
# 1       0.002059     0.881264    0.002059  0.881264  0.002059   0.891224
# 2       0.005005     0.967620    0.005005  0.967620  0.005005   0.972753
# 3       0.003437     0.941616    0.003437  0.941616  0.003437   0.950104
# 4       0.003191     0.876517    0.003191  0.876517  0.003191   0.890574
# 5       0.003992     0.868488    0.003992  0.868488  0.003992   0.888213
# 6       0.023750     0.678330    0.023750  0.678330  0.023750   0.738394
# 7       0.056143     0.753990    0.056143  0.753990  0.056143   0.818372
#
#    ndcg_std
# 0  0.001346
# 1  0.001819
# 2  0.004254
# 3  0.002936
# 4  0.002883
# 5  0.003268
# 6  0.019371
# 7  0.043211
