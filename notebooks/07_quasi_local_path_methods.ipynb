# %%
from functools import partial

from link_prediction.config import (
    load_methods_config,
)
from link_prediction.evaluation import (
    run_method_family_benchmark,
)
from link_prediction.methods.quasi_local_paths import (
    score_quasi_local_path_candidates,
)

# %%
method_config = (
    load_methods_config()[
        "methods"
    ][
        "lpi"
    ]
)

lpi_scorer = partial(
    score_quasi_local_path_candidates,
    **method_config["parameters"],
)

fold_metrics, network_summary = (
    run_method_family_benchmark(
        family_id="quasi_local_path",
        scorer=lpi_scorer,
        benchmark_name="standard",
    )
)

fold_metrics
# Out:
# quasi_local_path: 40 tasks, 6 workers
#     benchmark      network_id         network          domain  fold  \
# 0    standard    ego_facebook    ego-Facebook          social     1
# 1    standard    ego_facebook    ego-Facebook          social     1
# 2    standard    ego_facebook    ego-Facebook          social     1
# 3    standard    ego_facebook    ego-Facebook          social     2
# 4    standard    ego_facebook    ego-Facebook          social     2
# ..        ...             ...             ...             ...   ...
# 115  standard  power_1138_bus  power-1138-bus  infrastructure     4
# 116  standard  power_1138_bus  power-1138-bus  infrastructure     4
# 117  standard  power_1138_bus  power-1138-bus  infrastructure     5
# 118  standard  power_1138_bus  power-1138-bus  infrastructure     5
# 119  standard  power_1138_bus  power-1138-bus  infrastructure     5
#
#                family method_id  average_precision   roc_auc  precision  ...  \
# 0    quasi_local_path       lpi           0.991895  0.993329   0.968409  ...
# 1    quasi_local_path   ora_cni           0.988901  0.990313   0.952732  ...
# 2    quasi_local_path        fl           0.991967  0.993363   0.968409  ...
# 3    quasi_local_path       lpi           0.993063  0.994081   0.968644  ...
# 4    quasi_local_path   ora_cni           0.989588  0.990870   0.954154  ...
# ..                ...       ...                ...       ...        ...  ...
# 115  quasi_local_path   ora_cni           0.839009  0.838623   0.812500  ...
# 116  quasi_local_path        fl           0.838889  0.839600   0.812500  ...
# 117  quasi_local_path       lpi           0.757812  0.757812   0.687500  ...
# 118  quasi_local_path   ora_cni           0.757812  0.757812   0.687500  ...
# 119  quasi_local_path        fl           0.757812  0.757812   0.687500  ...
#
#      tied_candidate_ratio  largest_tie_group  cutoff_score  cutoff_tie_size  \
# 0                0.630285              11714      2.095000                2
# 1                0.406918              11714      1.850152                1
# 2                0.608848              11714      0.000498                2
# 3                0.630530              11263      2.067000                6
# 4                0.407803              11263      1.814035                1
# ..                    ...                ...           ...              ...
# 115              0.796875                 83      0.000000               83
# 116              0.960938                 83      0.000000               83
# 117              0.984375                 95      0.000000               95
# 118              0.820312                 95      0.000000               95
# 119              0.984375                 95      0.000000               95
#
#      cutoff_tie_positive_count  cutoff_tie_negative_count  \
# 0                            1                          1
# 1                            0                          1
# 2                            1                          1
# 3                            4                          2
# 4                            0                          1
# ..                         ...                        ...
# 115                         20                         63
# 116                         20                         63
# 117                         31                         64
# 118                         31                         64
# 119                         31                         64
#
#      cutoff_slots_in_tie  cutoff_tie_crosses_boundary              method  \
# 0                      2                        False      LPI-beta-0.001
# 1                      1                        False  ORA-CNI-beta-0.001
# 2                      2                        False               FL-l3
# 3                      3                         True      LPI-beta-0.001
# 4                      1                        False  ORA-CNI-beta-0.001
# ..                   ...                          ...                 ...
# 115                   19                         True  ORA-CNI-beta-0.001
# 116                   19                         True               FL-l3
# 117                   31                         True      LPI-beta-0.001
# 118                   31                         True  ORA-CNI-beta-0.001
# 119                   31                         True               FL-l3
#
#      family_scoring_seconds
# 0                 88.784597
# 1                 88.784597
# 2                 88.784597
# 3                 85.561227
# 4                 85.561227
# ..                      ...
# 115                0.005508
# 116                0.005508
# 117                0.005682
# 118                0.005682
# 119                0.005682
#
# [120 rows x 30 columns]

# %%
network_summary
# Out:
#    benchmark          network_id             network  \
# 0   standard        ego_facebook        ego-Facebook
# 1   standard        ego_facebook        ego-Facebook
# 2   standard        ego_facebook        ego-Facebook
# 3   standard  socfb_middlebury45  socfb-Middlebury45
# 4   standard  socfb_middlebury45  socfb-Middlebury45
# 5   standard  socfb_middlebury45  socfb-Middlebury45
# 6   standard             ca_grqc             ca-GrQc
# 7   standard             ca_grqc             ca-GrQc
# 8   standard             ca_grqc             ca-GrQc
# 9   standard            ca_hepth            ca-HepTh
# 10  standard            ca_hepth            ca-HepTh
# 11  standard            ca_hepth            ca-HepTh
# 12  standard       email_eu_core       email-Eu-core
# 13  standard       email_eu_core       email-Eu-core
# 14  standard       email_eu_core       email-Eu-core
# 15  standard          email_univ          email-univ
# 16  standard          email_univ          email-univ
# 17  standard          email_univ          email-univ
# 18  standard          power_grid          power-grid
# 19  standard          power_grid          power-grid
# 20  standard          power_grid          power-grid
# 21  standard      power_1138_bus      power-1138-bus
# 22  standard      power_1138_bus      power-1138-bus
# 23  standard      power_1138_bus      power-1138-bus
#
#                       domain            family method_id              method  \
# 0                     social  quasi_local_path       lpi      LPI-beta-0.001
# 1                     social  quasi_local_path   ora_cni  ORA-CNI-beta-0.001
# 2                     social  quasi_local_path        fl               FL-l3
# 3                     social  quasi_local_path       lpi      LPI-beta-0.001
# 4                     social  quasi_local_path   ora_cni  ORA-CNI-beta-0.001
# 5                     social  quasi_local_path        fl               FL-l3
# 6   scientific_collaboration  quasi_local_path       lpi      LPI-beta-0.001
# 7   scientific_collaboration  quasi_local_path   ora_cni  ORA-CNI-beta-0.001
# 8   scientific_collaboration  quasi_local_path        fl               FL-l3
# 9   scientific_collaboration  quasi_local_path       lpi      LPI-beta-0.001
# 10  scientific_collaboration  quasi_local_path   ora_cni  ORA-CNI-beta-0.001
# 11  scientific_collaboration  quasi_local_path        fl               FL-l3
# 12             communication  quasi_local_path       lpi      LPI-beta-0.001
# 13             communication  quasi_local_path   ora_cni  ORA-CNI-beta-0.001
# 14             communication  quasi_local_path        fl               FL-l3
# 15             communication  quasi_local_path       lpi      LPI-beta-0.001
# 16             communication  quasi_local_path   ora_cni  ORA-CNI-beta-0.001
# 17             communication  quasi_local_path        fl               FL-l3
# 18            infrastructure  quasi_local_path       lpi      LPI-beta-0.001
# 19            infrastructure  quasi_local_path   ora_cni  ORA-CNI-beta-0.001
# 20            infrastructure  quasi_local_path        fl               FL-l3
# 21            infrastructure  quasi_local_path       lpi      LPI-beta-0.001
# 22            infrastructure  quasi_local_path   ora_cni  ORA-CNI-beta-0.001
# 23            infrastructure  quasi_local_path        fl               FL-l3
#
#     average_precision_mean  average_precision_std  roc_auc_mean  ...  \
# 0                 0.992661               0.000598      0.993818  ...
# 1                 0.989161               0.000707      0.990545  ...
# 2                 0.992727               0.000592      0.993853  ...
# 3                 0.946727               0.000517      0.950232  ...
# 4                 0.917688               0.000936      0.927814  ...
# 5                 0.946964               0.000521      0.950325  ...
# 6                 0.982031               0.003164      0.981986  ...
# 7                 0.981854               0.003177      0.981755  ...
# 8                 0.982031               0.003164      0.981986  ...
# 9                 0.967846               0.001926      0.967725  ...
# 10                0.967891               0.001817      0.967537  ...
# 11                0.967846               0.001926      0.967725  ...
# 12                0.943182               0.002203      0.947013  ...
# 13                0.929817               0.002983      0.937139  ...
# 14                0.943188               0.002203      0.947014  ...
# 15                0.929082               0.004908      0.929138  ...
# 16                0.928739               0.002863      0.926871  ...
# 17                0.929082               0.004908      0.929138  ...
# 18                0.769892               0.010356      0.770922  ...
# 19                0.770049               0.009139      0.770960  ...
# 20                0.769892               0.010356      0.770922  ...
# 21                0.812590               0.036654      0.812788  ...
# 22                0.813457               0.036452      0.812454  ...
# 23                0.812590               0.036654      0.812788  ...
#
#     cutoff_tie_size_mean  cutoff_tie_size_std  cutoff_tie_positive_count_mean  \
# 0                    4.4             1.516575                             2.6
# 1                    1.0             0.000000                             0.2
# 2                    4.4             1.516575                             2.6
# 3                    3.4             2.073644                             1.8
# 4                    1.0             0.000000                             0.4
# 5                    3.4             2.073644                             1.8
# 6                 1504.0           810.590834                            55.6
# 7                 1493.4           834.292694                            51.2
# 8                 1504.0           810.590834                            55.6
# 9                 3354.6            17.184295                           196.0
# 10                3354.6            17.184295                           196.0
# 11                3354.6            17.184295                           196.0
# 12                   2.4             1.516575                             1.0
# 13                   1.0             0.000000                             0.4
# 14                   2.4             1.516575                             1.0
# 15                  42.6             2.701851                            19.2
# 16                   1.2             0.447214                             1.0
# 17                  42.6             2.701851                            19.2
# 18                 479.0             7.483315                           150.0
# 19                 479.0             7.483315                           150.0
# 20                 479.0             7.483315                           150.0
# 21                  87.0             4.949747                            23.6
# 22                  87.0             4.949747                            23.6
# 23                  87.0             4.949747                            23.6
#
#     cutoff_tie_positive_count_std  cutoff_tie_negative_count_mean  \
# 0                        1.341641                             1.8
# 1                        0.447214                             0.8
# 2                        1.341641                             1.8
# 3                        0.836660                             1.6
# 4                        0.547723                             0.6
# 5                        0.836660                             1.6
# 6                       19.165072                          1448.4
# 7                       28.873864                          1442.2
# 8                       19.165072                          1448.4
# 9                       12.649111                          3158.6
# 10                      12.649111                          3158.6
# 11                      12.649111                          3158.6
# 12                       0.707107                             1.4
# 13                       0.547723                             0.6
# 14                       0.707107                             1.4
# 15                       3.271085                            23.4
# 16                       0.707107                             0.2
# 17                       3.271085                            23.4
# 18                       7.280110                           329.0
# 19                       7.280110                           329.0
# 20                       7.280110                           329.0
# 21                       4.774935                            63.4
# 22                       4.774935                            63.4
# 23                       4.774935                            63.4
#
#     cutoff_tie_negative_count_std  cutoff_slots_in_tie_mean  \
# 0                        0.836660                       2.4
# 1                        0.447214                       1.0
# 2                        0.836660                       2.4
# 3                        1.816590                       2.2
# 4                        0.547723                       1.0
# 5                        1.816590                       2.4
# 6                      791.813299                      21.0
# 7                      805.676548                      11.0
# 8                      791.813299                      21.0
# 9                        7.402702                     120.8
# 10                       7.402702                     120.8
# 11                       7.402702                     120.8
# 12                       2.073644                       2.2
# 13                       0.547723                       1.0
# 14                       2.073644                       2.2
# 15                       2.701851                      13.2
# 16                       0.447214                       1.2
# 17                       2.701851                      13.2
# 18                       1.224745                     148.2
# 19                       1.224745                     148.2
# 20                       1.224745                     148.2
# 21                       0.547723                      22.8
# 22                       0.547723                      22.8
# 23                       0.547723                      22.8
#
#     cutoff_slots_in_tie_std  cutoff_tie_crosses_boundary_mean  \
# 0                  1.140175                               0.6
# 1                  0.000000                               0.0
# 2                  1.140175                               0.6
# 3                  0.836660                               0.4
# 4                  0.000000                               0.0
# 5                  0.894427                               0.4
# 6                 17.535678                               1.0
# 7                  7.582875                               0.8
# 8                 17.535678                               1.0
# 9                 17.340704                               1.0
# 10                17.340704                               1.0
# 11                17.340704                               1.0
# 12                 1.643168                               0.2
# 13                 0.000000                               0.0
# 14                 1.643168                               0.2
# 15                12.457929                               1.0
# 16                 0.447214                               0.0
# 17                12.457929                               1.0
# 18                 7.823043                               1.0
# 19                 7.823043                               1.0
# 20                 7.823043                               1.0
# 21                 5.019960                               1.0
# 22                 5.019960                               1.0
# 23                 5.019960                               1.0
#
#     cutoff_tie_crosses_boundary_std
# 0                          0.547723
# 1                          0.000000
# 2                          0.547723
# 3                          0.547723
# 4                          0.000000
# 5                          0.547723
# 6                          0.000000
# 7                          0.447214
# 8                          0.000000
# 9                          0.000000
# 10                         0.000000
# 11                         0.000000
# 12                         0.447214
# 13                         0.000000
# 14                         0.447214
# 15                         0.000000
# 16                         0.000000
# 17                         0.000000
# 18                         0.000000
# 19                         0.000000
# 20                         0.000000
# 21                         0.000000
# 22                         0.000000
# 23                         0.000000
#
# [24 rows x 39 columns]
