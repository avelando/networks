# %%
from link_prediction.profiling import prepare_benchmark

# %%
network_profiles, dataset_manifest = prepare_benchmark(
    benchmark_name="revision",
    overwrite=False,
)

network_profiles
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 network_profiles, dataset_manifest = prepare_benchmark(
#       2     benchmark_name="revision",
#       3     overwrite=False,
#       4 )
#
# File ~/networks/src/link_prediction/profiling.py:123, in prepare_benchmark(benchmark_name, overwrite)
#     120 if not network_config.get("enabled", True):
#     121     continue
# --> 123 _, profile, manifest = prepare_network(
#     124     network_id=network_id,
#     125     network_config=network_config,
#     126     graph_config=graph_config,
#     127     overwrite=overwrite,
#     128 )
#     130 profiles.append(profile)
#     131 manifests.append(manifest)
#
# File ~/networks/src/link_prediction/profiling.py:35, in prepare_network(network_id, network_config, graph_config, overwrite)
#      29 def prepare_network(
#      30     network_id: str,
#      31     network_config: dict[str, Any],
#      32     graph_config: dict[str, Any],
#      33     overwrite: bool = False,
#      34 ) -> tuple[nx.Graph, dict[str, Any], dict[str, Any]]:
# ---> 35     graph_path = prepare_dataset(
#      36         network_name=network_id,
#      37         network_config=network_config,
#      38         overwrite=overwrite,
#      39     )
#      41     raw_graph = load_graph(
#      42         path=graph_path,
#      43         parser_config=network_config["parser"],
#      44     )
#      46     processed_graph = standardize_graph(
#      47         graph=raw_graph,
#      48         make_undirected=not graph_config.get(
#    (...)     59         ),
#      60     )
#
# File ~/networks/src/link_prediction/datasets.py:211, in prepare_dataset(network_name, network_config, overwrite)
#     203     extraction_directory = RAW_DATA_DIR / network_name
#     205     extract_zip(
#     206         source=downloaded_path,
#     207         destination=extraction_directory,
#     208         overwrite=overwrite,
#     209     )
# --> 211     return resolve_extracted_file(
#     212         directory=extraction_directory,
#     213         member=member,
#     214         member_patterns=member_patterns,
#     215     )
#     217 raise ValueError(
#     218     f"Unsupported archive type for {network_name}: {archive_type}"
#     219 )
#
# File ~/networks/src/link_prediction/datasets.py:150, in resolve_extracted_file(directory, member, member_patterns)
#     147 if len(files) == 1:
#     148     return files[0]
# --> 150 raise FileNotFoundError(
#     151     f"Could not determine graph file in: {directory}"
#     152 )
#
# FileNotFoundError: Could not determine graph file in: /home/avelar/networks/data/raw/socfb_middlebury45

# %%
dataset_manifest
# Out:
#       network_id        network                    domain      role  \
# 0  email_eu_core  email-Eu-core             communication  original
# 1     power_grid     power-grid            infrastructure  original
# 2        ca_grqc        ca-GrQc  scientific_collaboration  original
# 3       ca_hepth       ca-HepTh  scientific_collaboration  original
# 4   ego_facebook   ego-Facebook                    social  original
#
#       repository                                         source_url  \
# 0           SNAP  https://snap.stanford.edu/data/email-Eu-core.t...
# 1  Netzschleuder  https://networks.skewed.de/net/power/files/pow...
# 2           SNAP      https://snap.stanford.edu/data/ca-GrQc.txt.gz
# 3           SNAP     https://snap.stanford.edu/data/ca-HepTh.txt.gz
# 4           SNAP  https://snap.stanford.edu/data/facebook_combin...
#
#                 source_file  \
# 0      email-Eu-core.txt.gz
# 1             power.csv.zip
# 2            ca-GrQc.txt.gz
# 3           ca-HepTh.txt.gz
# 4  facebook_combined.txt.gz
#
#                                        source_sha256  \
# 0  4b47acdb80197b085fe63c819c357ae488131ee904ed93...
# 1  66c051841053af1ebe488973fb579ff4f723566dc2ee28...
# 2  a254442cdf5d684712578b630c2e0d7543518ab154ef23...
# 3  7235c7e11887f8a32dfd03a3aa0c77efdf89d41591a959...
# 4  125e84db872eeba443d270c70315c256b0af43a502fcfe...
#
#                                           graph_file  \
# 0   /home/avelar/networks/data/raw/email-Eu-core.txt
# 1  /home/avelar/networks/data/raw/power_grid/edge...
# 2         /home/avelar/networks/data/raw/ca-GrQc.txt
# 3        /home/avelar/networks/data/raw/ca-HepTh.txt
# 4  /home/avelar/networks/data/raw/facebook_combin...
#
#                                       processed_file
# 0  /home/avelar/networks/data/processed/email-Eu-...
# 1  /home/avelar/networks/data/processed/power-gri...
# 2  /home/avelar/networks/data/processed/ca-GrQc.e...
# 3  /home/avelar/networks/data/processed/ca-HepTh....
# 4  /home/avelar/networks/data/processed/ego-Faceb...
