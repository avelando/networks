# %%
from link_prediction.profiling import prepare_benchmark

# %%
network_profiles, dataset_manifest = prepare_benchmark(
    benchmark_name="standard",
    overwrite=False,
)

network_profiles
# Out:
# network profiling: 8 tasks, 6 workers
#               network                    domain raw_graph_type  raw_directed  \
# 0       email-Eu-core             communication        DiGraph          True
# 1          email-univ             communication          Graph         False
# 2      power-1138-bus            infrastructure          Graph         False
# 3          power-grid            infrastructure          Graph         False
# 4             ca-GrQc  scientific_collaboration          Graph         False
# 5            ca-HepTh  scientific_collaboration          Graph         False
# 6        ego-Facebook                    social          Graph         False
# 7  socfb-Middlebury45                    social          Graph         False
#
#    raw_nodes  raw_edges  raw_undirected_nodes  raw_undirected_edges  \
# 0       1005      25571                  1005                 16064
# 1       1133       5451                  1133                  5451
# 2       1138       2596                  1138                  1458
# 3       4941       6594                  4941                  6594
# 4       5242      14496                  5242                 14484
# 5       9877      25998                  9877                 25973
# 6       4039      88234                  4039                 88234
# 7       3075     124610                  3075                124610
#
#    raw_components  processed_nodes  ...  largest_component_node_ratio  \
# 0              20              986  ...                      0.981095
# 1               1             1133  ...                      1.000000
# 2               1             1138  ...                      1.000000
# 3               1             4941  ...                      1.000000
# 4             355             4158  ...                      0.793209
# 5             429             8638  ...                      0.874557
# 6               1             4039  ...                      1.000000
# 7               4             3069  ...                      0.998049
#
#    largest_component_edge_ratio   density  average_degree  average_clustering  \
# 0                      1.000000  0.033080       32.584178            0.407050
# 1                      1.000000  0.008500        9.622242            0.220176
# 2                      1.000000  0.002254        2.562390            0.086615
# 3                      1.000000  0.000540        2.669095            0.080104
# 4                      0.926678  0.001553        6.455988            0.556878
# 5                      0.955069  0.000665        5.743459            0.481564
# 6                      1.000000  0.010820       43.691013            0.605547
# 7                      0.999976  0.026468       81.203649            0.282180
#
#    transitivity  degree_assortativity  processed_components  \
# 0      0.267392             -0.025743                     1
# 1      0.166250              0.078201                     1
# 2      0.093068             -0.080110                     1
# 3      0.103153              0.003457                     1
# 4      0.628894              0.639186                     1
# 5      0.281129              0.238915                     1
# 6      0.519174              0.063577                     1
# 7      0.210842              0.078415                     1
#
#            network_id               repository
# 0       email_eu_core                     SNAP
# 1          email_univ  Network Data Repository
# 2      power_1138_bus  Network Data Repository
# 3          power_grid            Netzschleuder
# 4             ca_grqc                     SNAP
# 5            ca_hepth                     SNAP
# 6        ego_facebook                     SNAP
# 7  socfb_middlebury45  Network Data Repository
#
# [8 rows x 23 columns]

# %%
dataset_manifest
# Out:
#            network_id             network                    domain  \
# 0       email_eu_core       email-Eu-core             communication
# 1          email_univ          email-univ             communication
# 2      power_1138_bus      power-1138-bus            infrastructure
# 3          power_grid          power-grid            infrastructure
# 4             ca_grqc             ca-GrQc  scientific_collaboration
# 5            ca_hepth            ca-HepTh  scientific_collaboration
# 6        ego_facebook        ego-Facebook                    social
# 7  socfb_middlebury45  socfb-Middlebury45                    social
#
#                 repository                                         source_url  \
# 0                     SNAP  https://snap.stanford.edu/data/email-Eu-core.t...
# 1  Network Data Repository  https://nrvis.com/download/data/ia/ia-email-un...
# 2  Network Data Repository  https://nrvis.com/download/data/power/power-11...
# 3            Netzschleuder  https://networks.skewed.de/net/power/files/pow...
# 4                     SNAP      https://snap.stanford.edu/data/ca-GrQc.txt.gz
# 5                     SNAP     https://snap.stanford.edu/data/ca-HepTh.txt.gz
# 6                     SNAP  https://snap.stanford.edu/data/facebook_combin...
# 7  Network Data Repository  https://nrvis.com/download/data/socfb/socfb-Mi...
#
#                 source_file  \
# 0      email-Eu-core.txt.gz
# 1         ia-email-univ.zip
# 2        power-1138-bus.zip
# 3             power.csv.zip
# 4            ca-GrQc.txt.gz
# 5           ca-HepTh.txt.gz
# 6  facebook_combined.txt.gz
# 7    socfb-Middlebury45.zip
#
#                                        source_sha256  \
# 0  4b47acdb80197b085fe63c819c357ae488131ee904ed93...
# 1  910de7179ec2268952c655f5137ea01b3179d9ecae1be8...
# 2  2239bc438049e971b8b1d3ccb95d404f2a8ec5fe727185...
# 3  66c051841053af1ebe488973fb579ff4f723566dc2ee28...
# 4  a254442cdf5d684712578b630c2e0d7543518ab154ef23...
# 5  7235c7e11887f8a32dfd03a3aa0c77efdf89d41591a959...
# 6  125e84db872eeba443d270c70315c256b0af43a502fcfe...
# 7  6daae42cd36567698690de59976de4be73debb666a7616...
#
#                                           graph_file  \
# 0                         data/raw/email-Eu-core.txt
# 1              data/raw/email_univ/ia-email-univ.mtx
# 2         data/raw/power_1138_bus/power-1138-bus.mtx
# 3                      data/raw/power_grid/edges.csv
# 4                               data/raw/ca-GrQc.txt
# 5                              data/raw/ca-HepTh.txt
# 6                     data/raw/facebook_combined.txt
# 7  data/raw/socfb_middlebury45/socfb-Middlebury45...
#
#                                processed_file
# 0       data/processed/email-Eu-core.edgelist
# 1          data/processed/email-univ.edgelist
# 2      data/processed/power-1138-bus.edgelist
# 3          data/processed/power-grid.edgelist
# 4             data/processed/ca-GrQc.edgelist
# 5            data/processed/ca-HepTh.edgelist
# 6        data/processed/ego-Facebook.edgelist
# 7  data/processed/socfb-Middlebury45.edgelist
