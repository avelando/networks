# %%
from link_prediction.evaluation import (
    run_method_family_benchmark,
)

from link_prediction.methods.degree_based import (
    score_degree_based_candidates,
)

# %%
fold_metrics, network_summary = (
    run_method_family_benchmark(
        family_id="degree_based",
        scorer=score_degree_based_candidates,
        benchmark_name="revision",
    )
)

fold_metrics
# Out:
#    benchmark          network_id             network  \
# 0   revision        ego_facebook        ego-Facebook
# 1   revision        ego_facebook        ego-Facebook
# 2   revision        ego_facebook        ego-Facebook
# 3   revision        ego_facebook        ego-Facebook
# 4   revision        ego_facebook        ego-Facebook
# 5   revision  socfb_middlebury45  socfb-Middlebury45
# 6   revision  socfb_middlebury45  socfb-Middlebury45
# 7   revision  socfb_middlebury45  socfb-Middlebury45
# 8   revision  socfb_middlebury45  socfb-Middlebury45
# 9   revision  socfb_middlebury45  socfb-Middlebury45
# 10  revision             ca_grqc             ca-GrQc
# 11  revision             ca_grqc             ca-GrQc
# 12  revision             ca_grqc             ca-GrQc
# 13  revision             ca_grqc             ca-GrQc
# 14  revision             ca_grqc             ca-GrQc
# 15  revision            ca_hepth            ca-HepTh
# 16  revision            ca_hepth            ca-HepTh
# 17  revision            ca_hepth            ca-HepTh
# 18  revision            ca_hepth            ca-HepTh
# 19  revision            ca_hepth            ca-HepTh
# 20  revision       email_eu_core       email-Eu-core
# 21  revision       email_eu_core       email-Eu-core
# 22  revision       email_eu_core       email-Eu-core
# 23  revision       email_eu_core       email-Eu-core
# 24  revision       email_eu_core       email-Eu-core
# 25  revision          email_univ          email-univ
# 26  revision          email_univ          email-univ
# 27  revision          email_univ          email-univ
# 28  revision          email_univ          email-univ
# 29  revision          email_univ          email-univ
# 30  revision          power_grid          power-grid
# 31  revision          power_grid          power-grid
# 32  revision          power_grid          power-grid
# 33  revision          power_grid          power-grid
# 34  revision          power_grid          power-grid
# 35  revision      power_1138_bus      power-1138-bus
# 36  revision      power_1138_bus      power-1138-bus
# 37  revision      power_1138_bus      power-1138-bus
# 38  revision      power_1138_bus      power-1138-bus
# 39  revision      power_1138_bus      power-1138-bus
#
#                       domain  fold        family method_id  average_precision  \
# 0                     social     1  degree_based        pa           0.852871
# 1                     social     2  degree_based        pa           0.853511
# 2                     social     3  degree_based        pa           0.849835
# 3                     social     4  degree_based        pa           0.856321
# 4                     social     5  degree_based        pa           0.851518
# 5                     social     1  degree_based        pa           0.774473
# 6                     social     2  degree_based        pa           0.773237
# 7                     social     3  degree_based        pa           0.774422
# 8                     social     4  degree_based        pa           0.774740
# 9                     social     5  degree_based        pa           0.771420
# 10  scientific_collaboration     1  degree_based        pa           0.856958
# 11  scientific_collaboration     2  degree_based        pa           0.866322
# 12  scientific_collaboration     3  degree_based        pa           0.859841
# 13  scientific_collaboration     4  degree_based        pa           0.865557
# 14  scientific_collaboration     5  degree_based        pa           0.865766
# 15  scientific_collaboration     1  degree_based        pa           0.831222
# 16  scientific_collaboration     2  degree_based        pa           0.837171
# 17  scientific_collaboration     3  degree_based        pa           0.836825
# 18  scientific_collaboration     4  degree_based        pa           0.836977
# 19  scientific_collaboration     5  degree_based        pa           0.834214
# 20             communication     1  degree_based        pa           0.871340
# 21             communication     2  degree_based        pa           0.857576
# 22             communication     3  degree_based        pa           0.864969
# 23             communication     4  degree_based        pa           0.865511
# 24             communication     5  degree_based        pa           0.872268
# 25             communication     1  degree_based        pa           0.814228
# 26             communication     2  degree_based        pa           0.821397
# 27             communication     3  degree_based        pa           0.826856
# 1            16839            33678     PA                0.024977
# 2            16839            33678     PA                0.024381
# 3            16839            33678     PA                0.024120
# 4            16839            33678     PA                0.024095
# 5            24308            48616     PA                0.033489
# 6            24308            48616     PA                0.033620
# 7            24308            48616     PA                0.033992
# 8            24308            48616     PA                0.032473
# 9            24307            48614     PA                0.032648
# 10            1853             3706     PA                0.004036
# 11            1853             3706     PA                0.003867
# 12            1853             3706     PA                0.003901
# 13            1853             3706     PA                0.003839
# 14            1853             3706     PA                0.003836
# 15            3234             6468     PA                0.007212
# 16            3234             6468     PA                0.007687
# 17            3234             6468     PA                0.007458
# 18            3234             6468     PA                0.007175
# 19            3233             6466     PA                0.007285
# 20            3016             6032     PA                0.004669
# 21            3016             6032     PA                0.004681
# 22            3016             6032     PA                0.004662
# 23            3016             6032     PA                0.004626
# 24            3015             6030     PA                0.004624
# 25             864             1728     PA                0.001955
# 26             864             1728     PA                0.001897
# 27             864             1728     PA                0.001910
# 28             864             1728     PA                0.001893
# 29             863             1726     PA                0.001930
# 30             331              662     PA                0.001995
# 31             331              662     PA                0.001932
# 32             331              662     PA                0.001863
# 33             331              662     PA                0.001881
# 34             330              660     PA                0.001945
# 35              65              130     PA                0.000844
# 36              64              128     PA                0.000841
# 37              64              128     PA                0.000819
# 38              64              128     PA                0.000821
# 39              64              128     PA                0.000807

# %%
network_summary
# Out:
#   benchmark          network_id             network                    domain  \
# 0  revision        ego_facebook        ego-Facebook                    social
# 1  revision  socfb_middlebury45  socfb-Middlebury45                    social
# 2  revision             ca_grqc             ca-GrQc  scientific_collaboration
# 3  revision            ca_hepth            ca-HepTh  scientific_collaboration
# 4  revision       email_eu_core       email-Eu-core             communication
# 5  revision          email_univ          email-univ             communication
# 6  revision          power_grid          power-grid            infrastructure
# 7  revision      power_1138_bus      power-1138-bus            infrastructure
#
#          family method_id method  average_precision_mean  \
# 0  degree_based        pa     PA                0.852811
# 1  degree_based        pa     PA                0.773658
# 2  degree_based        pa     PA                0.862889
# 3  degree_based        pa     PA                0.835282
# 4  degree_based        pa     PA                0.866333
# 5  degree_based        pa     PA                0.820688
# 6  degree_based        pa     PA                0.649446
# 7  degree_based        pa     PA                0.665319
#
#    average_precision_std  roc_auc_mean  roc_auc_std  precision_mean  \
# 0               0.002416      0.839610     0.003089        0.758896
# 1               0.001379      0.792116     0.001309        0.715507
# 2               0.004232      0.842192     0.005412        0.759741
# 3               0.002571      0.825388     0.002438        0.746305
# 4               0.005906      0.873323     0.004950        0.782479
# 5               0.005012      0.833994     0.008297        0.754805
# 6               0.023630      0.637492     0.021104        0.594919
# 7               0.048168      0.677354     0.061747        0.626394
#
#    precision_std  recall_mean  recall_std   f1_mean    f1_std  ndcg_mean  \
# 0       0.002834     0.758896    0.002834  0.758896  0.002834   0.777678
# 1       0.001618     0.715507    0.001618  0.715507  0.001618   0.728900
# 2       0.007030     0.759741    0.007030  0.759741  0.007030   0.789158
# 3       0.003391     0.746305    0.003391  0.746305  0.003391   0.771184
# 4       0.006308     0.782479    0.006308  0.782479  0.006308   0.802983
# 5       0.006042     0.754805    0.006042  0.754805  0.006042   0.780027
# 6       0.016750     0.594919    0.016750  0.594919  0.016750   0.635857
# 7       0.071474     0.626394    0.071474  0.626394  0.071474   0.659081
#
#    ndcg_std
# 0  0.002579
# 1  0.001539
# 2  0.006258
# 3  0.002855
# 4  0.005482
# 5  0.004706
# 6  0.018879
# 7  0.069936
