# %%
from link_prediction.evaluation import (
    run_method_family_benchmark,
)

from link_prediction.methods.degree_based import (
    score_degree_based_candidates,
)

# %%
fold_metrics, network_summary = (
    run_method_family_benchmark(
        family_id="degree_based",
        scorer=score_degree_based_candidates,
        benchmark_name="standard",
    )
)

fold_metrics
# Out:
# degree_based: 40 tasks, 6 workers
#    benchmark          network_id             network  \
# 0   standard        ego_facebook        ego-Facebook
# 1   standard        ego_facebook        ego-Facebook
# 2   standard        ego_facebook        ego-Facebook
# 3   standard        ego_facebook        ego-Facebook
# 4   standard        ego_facebook        ego-Facebook
# 5   standard  socfb_middlebury45  socfb-Middlebury45
# 6   standard  socfb_middlebury45  socfb-Middlebury45
# 7   standard  socfb_middlebury45  socfb-Middlebury45
# 8   standard  socfb_middlebury45  socfb-Middlebury45
# 9   standard  socfb_middlebury45  socfb-Middlebury45
# 10  standard             ca_grqc             ca-GrQc
# 11  standard             ca_grqc             ca-GrQc
# 12  standard             ca_grqc             ca-GrQc
# 13  standard             ca_grqc             ca-GrQc
# 14  standard             ca_grqc             ca-GrQc
# 15  standard            ca_hepth            ca-HepTh
# 16  standard            ca_hepth            ca-HepTh
# 17  standard            ca_hepth            ca-HepTh
# 18  standard            ca_hepth            ca-HepTh
# 19  standard            ca_hepth            ca-HepTh
# 20  standard       email_eu_core       email-Eu-core
# 21  standard       email_eu_core       email-Eu-core
# 22  standard       email_eu_core       email-Eu-core
# 23  standard       email_eu_core       email-Eu-core
# 24  standard       email_eu_core       email-Eu-core
# 25  standard          email_univ          email-univ
# 26  standard          email_univ          email-univ
# 27  standard          email_univ          email-univ
# 28  standard          email_univ          email-univ
# 29  standard          email_univ          email-univ
# 30  standard          power_grid          power-grid
# 31  standard          power_grid          power-grid
# 32  standard          power_grid          power-grid
# 33  standard          power_grid          power-grid
# 34  standard          power_grid          power-grid
# 35  standard      power_1138_bus      power-1138-bus
# 36  standard      power_1138_bus      power-1138-bus
# 37  standard      power_1138_bus      power-1138-bus
# 38  standard      power_1138_bus      power-1138-bus
# 39  standard      power_1138_bus      power-1138-bus
#
#                       domain  fold        family method_id  average_precision  \
# 0                     social     1  degree_based        pa           0.852871
# 1                     social     2  degree_based        pa           0.853511
# 2                     social     3  degree_based        pa           0.849835
# 3                     social     4  degree_based        pa           0.856321
# 4                     social     5  degree_based        pa           0.851518
# 5                     social     1  degree_based        pa           0.774473
# 6                     social     2  degree_based        pa           0.773237
# 7                     social     3  degree_based        pa           0.774422
# 8                     social     4  degree_based        pa           0.774740
# 9                     social     5  degree_based        pa           0.771420
# 10  scientific_collaboration     1  degree_based        pa           0.856958
# 11  scientific_collaboration     2  degree_based        pa           0.866322
# 12  scientific_collaboration     3  degree_based        pa           0.859841
# 13  scientific_collaboration     4  degree_based        pa           0.865557
# 14  scientific_collaboration     5  degree_based        pa           0.865766
# 15  scientific_collaboration     1  degree_based        pa           0.831222
# 16  scientific_collaboration     2  degree_based        pa           0.837171
# 17  scientific_collaboration     3  degree_based        pa           0.836825
# 18  scientific_collaboration     4  degree_based        pa           0.836977
# 19  scientific_collaboration     5  degree_based        pa           0.834214
# 20             communication     1  degree_based        pa           0.871340
# 21             communication     2  degree_based        pa           0.857576
# 22             communication     3  degree_based        pa           0.864969
# 23             communication     4  degree_based        pa           0.865511
# 24             communication     5  degree_based        pa           0.872268
# 25             communication     1  degree_based        pa           0.814228
# 26             communication     2  degree_based        pa           0.821397
# 27             communication     3  degree_based        pa           0.826856
# 28             communication     4  degree_based        pa           0.823651
# 29             communication     5  degree_based        pa           0.817308
# 30            infrastructure     1  degree_based        pa           0.640460
# 31            infrastructure     2  degree_based        pa           0.690873
# 32            infrastructure     3  degree_based        pa           0.644557
# 33            infrastructure     4  degree_based        pa           0.639738
# 34            infrastructure     5  degree_based        pa           0.631603
# 35            infrastructure     1  degree_based        pa           0.608093
# 36            infrastructure     2  degree_based        pa           0.720230
# 37            infrastructure     3  degree_based        pa           0.665782
# 38            infrastructure     4  degree_based        pa           0.704902
# 39            infrastructure     5  degree_based        pa           0.627590
#
#      roc_auc  precision  ...  tied_candidate_ratio  largest_tie_group  \
# 0   0.840643   0.758135  ...              0.932571                124
# 1   0.839181   0.759903  ...              0.932656                130
# 2   0.837050   0.757408  ...              0.935061                128
# 3   0.844358   0.763228  ...              0.934824                123
# 4   0.836816   0.755805  ...              0.939159                150
# 5   0.792915   0.715978  ...              0.942817                 51
# 6   0.791036   0.714538  ...              0.939012                 47
# 7   0.792342   0.715814  ...              0.940328                 52
# 8   0.793724   0.717747  ...              0.943249                 46
# 9   0.790563   0.713457  ...              0.943514                 46
# 10  0.836315   0.748516  ...              0.954128                183
# 11  0.848030   0.763627  ...              0.941176                203
# 12  0.836738   0.757151  ...              0.946303                194
# 13  0.843573   0.764166  ...              0.954128                218
# 14  0.846302   0.765246  ...              0.948192                193
# 15  0.824404   0.745516  ...              0.982375                339
# 16  0.825992   0.746444  ...              0.984385                333
# 17  0.829129   0.752010  ...              0.977737                351
# 18  0.824892   0.743661  ...              0.983148                324
# 19  0.822524   0.743891  ...              0.985153                333
# 20  0.879255   0.788793  ...              0.824768                 37
# 21  0.866335   0.771883  ...              0.840517                 46
# 22  0.870783   0.783156  ...              0.850630                 48
# 23  0.874387   0.784483  ...              0.836870                 38
# 24  0.875854   0.784080  ...              0.828524                 43
# 25  0.821782   0.744213  ...              0.938657                 49
# 26  0.834678   0.756944  ...              0.937500                 43
# 27  0.845001   0.758102  ...              0.939236                 46
# 28  0.835755   0.755787  ...              0.941551                 49
# 29  0.832756   0.758980  ...              0.940904                 48
# 30  0.634044   0.595166  ...              0.983384                112
# 31  0.674423   0.622356  ...              0.983384                112
# 32  0.628043   0.589124  ...              0.984894                 97
# 33  0.621759   0.577039  ...              0.986405                102
# 34  0.629192   0.590909  ...              0.993939                 98
# 35  0.606864   0.553846  ...              0.938462                 16
# 36  0.747192   0.703125  ...              0.960938                 21
# 37  0.659912   0.578125  ...              0.945312                 16
# 38  0.736084   0.703125  ...              0.953125                 21
# 39  0.636719   0.593750  ...              0.960938                 19
#
#     cutoff_score  cutoff_tie_size  cutoff_tie_positive_count  \
# 0         1284.0                1                          0
# 1         1258.0                6                          3
# 2         1225.0               10                          5
# 3         1242.0               15                         11
# 4         1270.0                4                          0
# 5         5073.0                5                          1
# 6         5040.0               39                         21
# 7         5016.0               17                          9
# 8         5100.0               23                         11
# 9         5040.0               44                         21
# 10          28.0               39                         21
# 11          30.0               60                         33
# 12          30.0               44                         29
# 13          30.0               49                         23
# 14          28.0               45                         27
# 15          25.0               37                         18
# 16          24.0              143                         59
# 17          24.0              140                         62
# 18          24.0              161                         78
# 19          24.0              151                         76
# 20         780.0                9                          6
# 21         782.0                8                          5
# 22         800.0                5                          5
# 23         768.0                7                          3
# 24         810.0                6                          1
# 25          70.0               12                          7
# 26          72.0               16                          9
# 27          72.0               12                          8
# 28          70.0               17                          9
# 29          70.0               16                          5
# 30           5.0               26                         11
# 31           6.0               69                         30
# 32           6.0               73                         28
# 33           6.0               81                         30
# 34           6.0               72                         30
# 35           6.0               12                          3
# 36           6.0               14                          8
# 37           6.0               15                          8
# 38           6.0               19                         10
# 39           5.0                7                          5
#
#     cutoff_tie_negative_count  cutoff_slots_in_tie  \
# 0                           1                    1
# 1                           3                    2
# 2                           5                    5
# 3                           4                   15
# 4                           4                    4
# 5                           4                    1
# 6                          18                   29
# 7                           8                    5
# 8                          12                   14
# 9                          23                   14
# 10                         18                   15
# 11                         27                   39
# 12                         15                   24
# 13                         26                   48
# 14                         18                   23
# 15                         19                   29
# 16                         84                   13
# 17                         78                   13
# 18                         83                   39
# 19                         75                   27
# 20                          3                    7
# 21                          3                    2
# 22                          0                    5
# 23                          4                    2
# 24                          5                    4
# 25                          5                    1
# 26                          7                   10
# 27                          4                   12
# 28                          8                    4
# 29                         11                    5
# 30                         15                    4
# 31                         39                   39
# 32                         45                   44
# 33                         51                   48
# 34                         42                   69
# 35                          9                    8
# 36                          6                    7
# 37                          7                    4
# 38                          9                   18
# 39                          2                    4
#
#     cutoff_tie_crosses_boundary  method  family_scoring_seconds
# 0                         False      PA                0.081405
# 1                          True      PA                0.065976
# 2                          True      PA                0.082927
# 3                         False      PA                0.129357
# 4                         False      PA                0.066417
# 5                          True      PA                0.083728
# 6                          True      PA                0.072130
# 7                          True      PA                0.073058
# 8                          True      PA                0.074644
# 9                          True      PA                0.078080
# 10                         True      PA                0.010660
# 11                         True      PA                0.010510
# 12                         True      PA                0.010378
# 13                         True      PA                0.010421
# 14                         True      PA                0.010174
# 15                         True      PA                0.017876
# 16                         True      PA                0.017171
# 17                         True      PA                0.018636
# 18                         True      PA                0.017973
# 19                         True      PA                0.033494
# 20                         True      PA                0.011019
# 21                         True      PA                0.011906
# 22                        False      PA                0.010537
# 23                         True      PA                0.010887
# 24                         True      PA                0.010805
# 25                         True      PA                0.005280
# 26                         True      PA                0.005701
# 27                        False      PA                0.005497
# 28                         True      PA                0.005710
# 29                         True      PA                0.005762
# 30                         True      PA                0.005893
# 31                         True      PA                0.005950
# 32                         True      PA                0.006202
# 33                         True      PA                0.005978
# 34                         True      PA                0.006060
# 35                         True      PA                0.003011
# 36                         True      PA                0.003173
# 37                         True      PA                0.003152
# 38                         True      PA                0.003353
# 39                         True      PA                0.003165
#
# [40 rows x 30 columns]

# %%
network_summary
# Out:
#   benchmark          network_id             network                    domain  \
# 0  standard        ego_facebook        ego-Facebook                    social
# 1  standard  socfb_middlebury45  socfb-Middlebury45                    social
# 2  standard             ca_grqc             ca-GrQc  scientific_collaboration
# 3  standard            ca_hepth            ca-HepTh  scientific_collaboration
# 4  standard       email_eu_core       email-Eu-core             communication
# 5  standard          email_univ          email-univ             communication
# 6  standard          power_grid          power-grid            infrastructure
# 7  standard      power_1138_bus      power-1138-bus            infrastructure
#
#          family method_id method  average_precision_mean  \
# 0  degree_based        pa     PA                0.852811
# 1  degree_based        pa     PA                0.773658
# 2  degree_based        pa     PA                0.862889
# 3  degree_based        pa     PA                0.835282
# 4  degree_based        pa     PA                0.866333
# 5  degree_based        pa     PA                0.820688
# 6  degree_based        pa     PA                0.649446
# 7  degree_based        pa     PA                0.665319
#
#    average_precision_std  roc_auc_mean  ...  cutoff_tie_size_mean  \
# 0               0.002416      0.839610  ...                   7.2
# 1               0.001379      0.792116  ...                  25.6
# 2               0.004232      0.842192  ...                  47.4
# 3               0.002571      0.825388  ...                 126.4
# 4               0.005906      0.873323  ...                   7.0
# 5               0.005012      0.833994  ...                  14.6
# 6               0.023630      0.637492  ...                  64.2
# 7               0.048168      0.677354  ...                  13.4
#
#    cutoff_tie_size_std  cutoff_tie_positive_count_mean  \
# 0             5.449771                             3.8
# 1            15.993749                            12.6
# 2             7.893035                            26.6
# 3            50.633981                            58.6
# 4             1.581139                             4.0
# 5             2.408319                             7.6
# 6            21.810548                            25.8
# 7             4.393177                             6.8
#
#    cutoff_tie_positive_count_std  cutoff_tie_negative_count_mean  \
# 0                       4.549725                             3.4
# 1                       8.532292                            13.0
# 2                       4.774935                            20.8
# 3                      24.182638                            67.8
# 4                       2.000000                             3.0
# 5                       1.673320                             7.0
# 6                       8.318654                            38.4
# 7                       2.774887                             6.6
#
#    cutoff_tie_negative_count_std  cutoff_slots_in_tie_mean  \
# 0                       1.516575                       5.4
# 1                       7.615773                      12.6
# 2                       5.357238                      29.8
# 3                      27.526351                      24.2
# 4                       1.870829                       4.0
# 5                       2.738613                       6.4
# 6                      13.813037                      40.8
# 7                       2.880972                       8.2
#
#    cutoff_slots_in_tie_std  cutoff_tie_crosses_boundary_mean  \
# 0                 5.594640                               0.4
# 1                10.784248                               1.0
# 2                13.367872                               1.0
# 3                11.189281                               1.0
# 4                 2.121320                               0.8
# 5                 4.505552                               0.8
# 6                23.530831                               1.0
# 7                 5.761944                               1.0
#
#    cutoff_tie_crosses_boundary_std
# 0                         0.547723
# 1                         0.000000
# 2                         0.000000
# 3                         0.000000
# 4                         0.447214
# 5                         0.447214
# 6                         0.000000
# 7                         0.000000
#
# [8 rows x 39 columns]
